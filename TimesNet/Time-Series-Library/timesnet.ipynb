# %% [markdown]
# Check GPU Runtime

# %%
# !nvidia-smi
# Out:
# Mon Feb 16 12:09:22 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# Clone repo

# %%
from getpass import getpass
TOKEN = getpass("Enter your GitHub PAT: ")
# !git clone https://{TOKEN}@github.com/fanniferenczi/TSAD.git
# Out:
# Cloning into 'TSAD'...
# remote: Enumerating objects: 451, done.
# remote: Counting objects: 100% (451/451), done.
# remote: Compressing objects: 100% (175/175), done.
# remote: Total 451 (delta 261), reused 448 (delta 258), pack-reused 0 (from 0)
# Receiving objects: 100% (451/451), 6.89 MiB | 36.92 MiB/s, done.
# Resolving deltas: 100% (261/261), done.

# %%
# %ls
# Out:
# sample_data  TSAD

# %%
# %cd TSAD/TimesNet/Time-Series-Library
# Out:
# /content/TSAD/TimesNet/Time-Series-Library

# %%
# %ls
# Out:
# CONTRIBUTING.md     Dockerfile  LICENSE  README.md         run.py     utils/
# data_provider/      exp/        models/  README_zh.md      scripts/
# docker-compose.yml  layers/     pic/     requirements.txt  tutorial/

# %% [markdown]
# Install dependencies

# %%
# !pip install einops reformer-pytorch local-attention sktime sympy PyWavelets patool tqdm 2>&1 | tail -5
# Out:
# Downloading product_key_memory-0.3.0-py3-none-any.whl (8.3 kB)
# Downloading CoLT5_attention-0.11.1-py3-none-any.whl (18 kB)
# Downloading torch_einops_utils-0.0.29-py3-none-any.whl (7.2 kB)
# Installing collected packages: scikit-base, patool, sktime, torch-einops-utils, axial-positional-embedding, hyper-connections, local-attention, colt5-attention, product-key-memory, reformer-pytorch
# Successfully installed axial-positional-embedding-0.3.12 colt5-attention-0.11.1 hyper-connections-0.4.9 local-attention-1.11.2 patool-4.0.4 product-key-memory-0.3.0 reformer-pytorch-1.4.4 scikit-base-0.13.1 sktime-0.40.1 torch-einops-utils-0.0.29

# %% [markdown]
# Run TimesNet anomaly detection on MSL dataset (GPU)

# %%
# !python -u run.py \
  --task_name anomaly_detection \
  --is_training 1 \
  --root_path ./dataset/MSL \
  --model_id MSL \
  --model TimesNet \
  --data MSL \
  --features M \
  --seq_len 100 \
  --pred_len 0 \
  --d_model 8 \
  --d_ff 16 \
  --e_layers 1 \
  --enc_in 55 \
  --c_out 55 \
  --top_k 3 \
  --anomaly_ratio 1 \
  --batch_size 128 \
  --train_epochs 1
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          anomaly_detection   Is Training:        1
#   Model ID:           MSL                 Model:              TimesNet
#
# Data Loader
#   Data:               MSL                 Root Path:          ./dataset/MSL
#   Data Path:          ETTh1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Anomaly Detection Task
#   Anomaly Ratio:      1.0
#
# Model Parameters
#   Top k:              3                   Num Kernels:        6
#   Enc In:             55                  Dec In:             7
#   C Out:              55                  d model:            8
#   n heads:            8                   e layers:           1
#   d layers:           1                   d FF:               16
#   Moving Avg:         25                  Factor:             1
#   Distil:             1                   Dropout:            0.1
#   Embed:              timeF               Activation:         gelu
#
# Run Parameters
#   Num Workers:        10                  Itr:                1
#   Train Epochs:       1                   Batch Size:         128
#   Patience:           3                   Learning Rate:      0.0001
#   Des:                test                Loss:               MSE
#   Lradj:              type1               Use Amp:            0
#
# GPU
#   Use GPU:            1                   GPU:                0
#   Use Multi GPU:      0                   Devices:            0,1,2,3
#
# De-stationary Projector Params
#   P Hidden Dims:      128, 128            P Hidden Layers:    2
#
# Use GPU: cuda:0
# >>>>>>>start training : anomaly_detection_MSL_TimesNet_MSL_ftM_sl100_ll48_pl0_dm8_nh8_el1_dl1_df16_expand2_dc4_fc1_ebtimeF_dtTrue_test_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# MSL/MSL_train.npy: 100% 25.7M/25.7M [00:00<00:00, 35.8MB/s]
# MSL/MSL_test.npy: 100% 32.4M/32.4M [00:00<00:00, 102MB/s]
# MSL/MSL_test_label.npy: 100% 73.9k/73.9k [00:00<00:00, 265kB/s]
# test: (73729, 55)
# train: (58317, 55)
# train 58218
# test: (73729, 55)
# train: (58317, 55)
# val 11565
# test: (73729, 55)
# train: (58317, 55)
# test 73630
# 	iters: 100, epoch: 1 | loss: 0.5125326
# 	speed: 0.0789s/iter; left time: 28.0831s
# 	iters: 200, epoch: 1 | loss: 0.5676856
# 	speed: 0.0322s/iter; left time: 8.2352s
# 	iters: 300, epoch: 1 | loss: 0.7707783
# 	speed: 0.0312s/iter; left time: 4.8663s
# 	iters: 400, epoch: 1 | loss: 0.5098114
# 	speed: 0.0308s/iter; left time: 1.7259s
# Epoch: 1 cost time: 19.175078630447388
# Epoch: 1, Steps: 455 | Train Loss: 0.6173452 Vali Loss: 0.4966897 Test Loss: 1.5204401
# Validation loss decreased (inf --> 0.496690).  Saving model ...
# Updating learning rate to 0.0001
# >>>>>>>testing : anomaly_detection_MSL_TimesNet_MSL_ftM_sl100_ll48_pl0_dm8_nh8_el1_dl1_df16_expand2_dc4_fc1_ebtimeF_dtTrue_test_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# test: (73729, 55)
# train: (58317, 55)
# test 73630
# test: (73729, 55)
# train: (58317, 55)
# train 58218
# Threshold : 9.525795
# pred:    (7363000,)
# gt:      (7363000,)
# pred:  (7363000,)
# gt:    (7363000,)
# Accuracy : 0.9647, Precision : 0.8955, Recall : 0.7529, F-score : 0.8180

# %% [markdown]
# Download & prepare GECCO 2018 Water Quality dataset

# %%
# !python scripts/prepare_gecco.py

# %% [markdown]
# Run TimesNet anomaly detection on GECCO dataset (GPU)

# %%
# !python -u run.py \
  --task_name anomaly_detection \
  --is_training 1 \
  --root_path ./dataset/GECCO \
  --model_id GECCO \
  --model TimesNet \
  --data GECCO \
  --features M \
  --seq_len 100 \
  --pred_len 0 \
  --d_model 32 \
  --d_ff 64 \
  --e_layers 2 \
  --enc_in 9 \
  --c_out 9 \
  --top_k 3 \
  --anomaly_ratio 1 \
  --batch_size 128 \
  --train_epochs 3
