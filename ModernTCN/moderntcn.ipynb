# %% [markdown]
# # ModernTCN

# %% [markdown]
# ## Setup Conda Environment (First Time Only)
#
# Run this in a terminal once to create the environment:

# %%
# Create conda environment (only run once)
# !conda create -n moderntcn python=3.9 -y

# %% [markdown]
# Now you can choose the newly created env as a runtime for this notebook, so you can run the following cells in the notebook.

# %%
# Register environment as Jupyter kernel (only run once)
# !conda run -n moderntcn pip install ipykernel
# !conda run -n moderntcn python -m ipykernel install --user --name=moderntcn --display-name "Python (moderntcn)"

# %% [markdown]
# ### Navigate to Project Directory

# %%
# %cd /home/fzf/dev/TSAD/ModernTCN
# Out:
# /home/fzf/dev/TSAD/ModernTCN

# %% [markdown]
# ### Install Dependencies

# %%
# Verify we're using the correct environment
import sys
print(f"Python path: {sys.executable}")
# Out:
# Python path: /home/fzf/.conda/envs/moderntcn/bin/python

# %%
# Install requirements
# !pip install -r requirements.txt

# Needed for the "Number of Operations" (MACs) section
# !pip install fvcore thop
# Out:
# Requirement already satisfied: einops in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (0.8.2)
# Requirement already satisfied: matplotlib in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (3.9.4)
# Requirement already satisfied: numpy in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: pandas in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (2.3.3)
# Requirement already satisfied: patool in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (1.15.0)
# Requirement already satisfied: reformer-pytorch in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (1.4.4)
# Requirement already satisfied: scikit-learn in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (1.6.1)
# Requirement already satisfied: scipy in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (1.13.1)
# Requirement already satisfied: sktime in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (0.38.5)
# Requirement already satisfied: sympy in /home/fzf/.local/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (1.14.0)
# Requirement already satisfied: torch in /home/fzf/.local/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (2.8.0)
# Requirement already satisfied: tqdm in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (4.67.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 2)) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 2)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 2)) (26.0)
# Requirement already satisfied: pillow>=8 in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 2)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 2)) (6.5.2)
# Requirement already satisfied: pytz>=2020.1 in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 4)) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 4)) (2025.3)
# Requirement already satisfied: axial-positional-embedding>=0.1.0 in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from reformer-pytorch->-r requirements.txt (line 6)) (0.3.12)
# Requirement already satisfied: local-attention in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from reformer-pytorch->-r requirements.txt (line 6)) (1.11.2)
# Requirement already satisfied: product-key-memory in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from reformer-pytorch->-r requirements.txt (line 6)) (0.3.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 7)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 7)) (3.6.0)
# Requirement already satisfied: scikit-base<0.13.0,>=0.6.1 in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from sktime->-r requirements.txt (line 9)) (0.12.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/fzf/.local/lib/python3.9/site-packages (from sympy->-r requirements.txt (line 10)) (1.3.0)
# Requirement already satisfied: filelock in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from torch->-r requirements.txt (line 11)) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/fzf/.local/lib/python3.9/site-packages (from torch->-r requirements.txt (line 11)) (4.15.0)
# Requirement already satisfied: networkx in /home/fzf/.local/lib/python3.9/site-packages (from torch->-r requirements.txt (line 11)) (3.2.1)
# Requirement already satisfied: jinja2 in /home/fzf/.local/lib/python3.9/site-packages (from torch->-r requirements.txt (line 11)) (3.1.6)
# Requirement already satisfied: fsspec in /home/fzf/.local/lib/python3.9/site-packages (from torch->-r requirements.txt (line 11)) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/fzf/.local/lib/python3.9/site-packages (from torch->-r requirements.txt (line 11)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/fzf/.local/lib/python3.9/site-packages (from torch->-r requirements.txt (line 11)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/fzf/.local/lib/python3.9/site-packages (from torch->-r requirements.txt (line 11)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/fzf/.local/lib/python3.9/site-packages (from torch->-r requirements.txt (line 11)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/fzf/.local/lib/python3.9/site-packages (from torch->-r requirements.txt (line 11)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/fzf/.local/lib/python3.9/site-packages (from torch->-r requirements.txt (line 11)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/fzf/.local/lib/python3.9/site-packages (from torch->-r requirements.txt (line 11)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/fzf/.local/lib/python3.9/site-packages (from torch->-r requirements.txt (line 11)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/fzf/.local/lib/python3.9/site-packages (from torch->-r requirements.txt (line 11)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/fzf/.local/lib/python3.9/site-packages (from torch->-r requirements.txt (line 11)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /home/fzf/.local/lib/python3.9/site-packages (from torch->-r requirements.txt (line 11)) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/fzf/.local/lib/python3.9/site-packages (from torch->-r requirements.txt (line 11)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/fzf/.local/lib/python3.9/site-packages (from torch->-r requirements.txt (line 11)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/fzf/.local/lib/python3.9/site-packages (from torch->-r requirements.txt (line 11)) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /home/fzf/.local/lib/python3.9/site-packages (from torch->-r requirements.txt (line 11)) (3.4.0)
# Requirement already satisfied: setuptools>=40.8.0 in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from triton==3.4.0->torch->-r requirements.txt (line 11)) (80.9.0)
# Requirement already satisfied: importlib-metadata in /home/fzf/.local/lib/python3.9/site-packages (from triton==3.4.0->torch->-r requirements.txt (line 11)) (8.7.1)
# Requirement already satisfied: zipp>=3.1.0 in /home/fzf/.local/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->-r requirements.txt (line 2)) (3.23.0)
# Requirement already satisfied: six>=1.5 in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/fzf/.local/lib/python3.9/site-packages (from jinja2->torch->-r requirements.txt (line 11)) (3.0.3)
# Requirement already satisfied: hyper-connections>=0.1.8 in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from local-attention->reformer-pytorch->-r requirements.txt (line 6)) (0.4.9)
# Requirement already satisfied: torch-einops-utils>=0.0.20 in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from hyper-connections>=0.1.8->local-attention->reformer-pytorch->-r requirements.txt (line 6)) (0.0.30)
# Requirement already satisfied: colt5-attention>=0.10.14 in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from product-key-memory->reformer-pytorch->-r requirements.txt (line 6)) (0.11.1)
# Collecting fvcore
#   Using cached fvcore-0.1.5.post20221221-py3-none-any.whl
# Collecting thop
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: numpy in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from fvcore) (2.0.2)
# Collecting yacs>=0.1.6 (from fvcore)
#   Using cached yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Collecting pyyaml>=5.1 (from fvcore)
#   Using cached pyyaml-6.0.3-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# Requirement already satisfied: tqdm in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from fvcore) (4.67.3)
# Collecting termcolor>=1.1 (from fvcore)
#   Using cached termcolor-3.1.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: Pillow in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from fvcore) (11.3.0)
# Collecting tabulate (from fvcore)
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting iopath>=0.1.7 (from fvcore)
#   Using cached iopath-0.1.10-py3-none-any.whl
# Requirement already satisfied: torch in /home/fzf/.local/lib/python3.9/site-packages (from thop) (2.8.0)
# Requirement already satisfied: typing_extensions in /home/fzf/.local/lib/python3.9/site-packages (from iopath>=0.1.7->fvcore) (4.15.0)
# Collecting portalocker (from iopath>=0.1.7->fvcore)
#   Using cached portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: filelock in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from torch->thop) (3.19.1)
# Requirement already satisfied: sympy>=1.13.3 in /home/fzf/.local/lib/python3.9/site-packages (from torch->thop) (1.14.0)
# Requirement already satisfied: networkx in /home/fzf/.local/lib/python3.9/site-packages (from torch->thop) (3.2.1)
# Requirement already satisfied: jinja2 in /home/fzf/.local/lib/python3.9/site-packages (from torch->thop) (3.1.6)
# Requirement already satisfied: fsspec in /home/fzf/.local/lib/python3.9/site-packages (from torch->thop) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/fzf/.local/lib/python3.9/site-packages (from torch->thop) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/fzf/.local/lib/python3.9/site-packages (from torch->thop) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/fzf/.local/lib/python3.9/site-packages (from torch->thop) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/fzf/.local/lib/python3.9/site-packages (from torch->thop) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/fzf/.local/lib/python3.9/site-packages (from torch->thop) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/fzf/.local/lib/python3.9/site-packages (from torch->thop) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/fzf/.local/lib/python3.9/site-packages (from torch->thop) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/fzf/.local/lib/python3.9/site-packages (from torch->thop) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/fzf/.local/lib/python3.9/site-packages (from torch->thop) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/fzf/.local/lib/python3.9/site-packages (from torch->thop) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /home/fzf/.local/lib/python3.9/site-packages (from torch->thop) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/fzf/.local/lib/python3.9/site-packages (from torch->thop) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/fzf/.local/lib/python3.9/site-packages (from torch->thop) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/fzf/.local/lib/python3.9/site-packages (from torch->thop) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /home/fzf/.local/lib/python3.9/site-packages (from torch->thop) (3.4.0)
# Requirement already satisfied: setuptools>=40.8.0 in /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages (from triton==3.4.0->torch->thop) (80.9.0)
# Requirement already satisfied: importlib-metadata in /home/fzf/.local/lib/python3.9/site-packages (from triton==3.4.0->torch->thop) (8.7.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/fzf/.local/lib/python3.9/site-packages (from sympy>=1.13.3->torch->thop) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in /home/fzf/.local/lib/python3.9/site-packages (from importlib-metadata->triton==3.4.0->torch->thop) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/fzf/.local/lib/python3.9/site-packages (from jinja2->torch->thop) (3.0.3)
# Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Using cached pyyaml-6.0.3-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (750 kB)
# Using cached termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Using cached yacs-0.1.8-py3-none-any.whl (14 kB)
# Using cached portalocker-3.2.0-py3-none-any.whl (22 kB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Installing collected packages: termcolor, tabulate, pyyaml, portalocker, yacs, iopath, fvcore, thop
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [thop]6/8 [fvcore]
# Successfully installed fvcore-0.1.5.post20221221 iopath-0.1.10 portalocker-3.2.0 pyyaml-6.0.3 tabulate-0.9.0 termcolor-3.1.0 thop-0.1.1.post2209072238 yacs-0.1.8

# %%
# %cd ./ModernTCN-detection
# Out:
# /home/fzf/dev/TSAD/ModernTCN/ModernTCN-detection

# %% [markdown]
# ## Run ModernTCN

# %% [markdown]
# Check GPU Availability

# %%
# !nvidia-smi

# %% [markdown]
# Select booked GPU

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '2, 3'

# %% [markdown]
# ### SMD Dataset

# %%
# !sh ./scripts/SMD.sh
# Out:
# Args in experiment:
# Namespace(random_seed=2021, is_training=1, model_id='SMD', model='ModernTCN', data='SMD', root_path='./all_datasets/SMD/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', embed='timeF', seq_len=100, label_len=0, pred_len=0, stem_ratio=6, downsample_ratio=2, ffn_ratio=1, patch_size=8, patch_stride=4, num_blocks=[1], large_size=[71], small_size=[5], dims=[32], dw_dims=[256, 256, 256, 256], small_kernel_merged=False, call_structural_reparam=False, use_multi_scale=False, fc_dropout=0.05, head_dropout=0.0, patch_len=16, stride=8, padding_patch='end', revin=1, affine=0, subtract_last=0, decomposition=0, kernel_size=25, individual=0, embed_type=0, enc_in=38, dec_in=7, c_out=38, d_model=512, n_heads=8, e_layers=2, d_layers=1, d_ff=2048, moving_avg=25, factor=1, distil=True, dropout=0.1, activation='gelu', output_attention=False, do_predict=False, num_workers=10, itr=1, train_epochs=1, batch_size=128, patience=10, learning_rate=0.0005, des='Exp', loss='mse', lradj='type1', pct_start=0.3, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', test_flop=False, task_name='anomaly_detection', seasonal_patterns='Monthly', mask_rate=0.25, anomaly_ratio=0.5, class_dropout=0.05)
# Use GPU: cuda:0
# >>>>>>>start training : SMD_ModernTCN_SMD_ftM_dim32_nb1_lk71_sk5_ffr1_ps8_str4_multiFalse_mergedFalse_Exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 7084
# val 1416
# test 7084
# Epoch: 1 cost time: 2.1269960403442383
# Epoch: 1, Steps: 56 | Train Loss: 0.2885610 Vali Loss: 0.2130297 Test Loss: 1.0833590
# Validation loss decreased (inf --> 0.213030).  Saving model ...
# Updating learning rate to 0.0005
# >>>>>>>testing : SMD_ModernTCN_SMD_ftM_dim32_nb1_lk71_sk5_ffr1_ps8_str4_multiFalse_mergedFalse_Exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 7084
# train 7084
# Threshold : 5.634075
# pred:    (708400,)
# gt:      (708400,)
# pred:  (708400,)
# gt:    (708400,)
# Accuracy : 0.9875, Precision : 0.8743, Recall : 0.8164, F-score : 0.8444

# %% [markdown]
# ### MSL Dataset

# %%
# !sh ./scripts/MSL.sh
# Out:
# Args in experiment:
# Namespace(random_seed=2021, is_training=1, model_id='MSL', model='ModernTCN', data='MSL', root_path='./all_datasets/MSL/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', embed='timeF', seq_len=96, label_len=48, pred_len=96, stem_ratio=6, downsample_ratio=2, ffn_ratio=1, patch_size=8, patch_stride=4, num_blocks=[1], large_size=[51], small_size=[5], dims=[8], dw_dims=[256, 256, 256, 256], small_kernel_merged=False, call_structural_reparam=False, use_multi_scale=False, fc_dropout=0.05, head_dropout=0.0, patch_len=16, stride=8, padding_patch='end', revin=1, affine=0, subtract_last=0, decomposition=0, kernel_size=25, individual=0, embed_type=0, enc_in=55, dec_in=7, c_out=55, d_model=512, n_heads=8, e_layers=2, d_layers=1, d_ff=2048, moving_avg=25, factor=1, distil=True, dropout=0.1, activation='gelu', output_attention=False, do_predict=False, num_workers=10, itr=1, train_epochs=2, batch_size=128, patience=10, learning_rate=0.0005, des='Exp', loss='mse', lradj='type1', pct_start=0.3, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', test_flop=False, task_name='anomaly_detection', seasonal_patterns='Monthly', mask_rate=0.25, anomaly_ratio=1.0, class_dropout=0.05)
# Use GPU: cuda:0
# >>>>>>>start training : MSL_ModernTCN_MSL_ftM_dim8_nb1_lk51_sk5_ffr1_ps8_str4_multiFalse_mergedFalse_Exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# test: (73729, 55)
# train: (58317, 55)
# train 58222
# test: (73729, 55)
# train: (58317, 55)
# val 73634
# test: (73729, 55)
# train: (58317, 55)
# test 73634
# 	iters: 100, epoch: 1 | loss: 0.6366570
# 	speed: 0.0333s/iter; left time: 27.0193s
# 	iters: 200, epoch: 1 | loss: 0.5988888
# 	speed: 0.0121s/iter; left time: 8.5874s
# 	iters: 300, epoch: 1 | loss: 0.9277945
# 	speed: 0.0135s/iter; left time: 8.2532s
# 	iters: 400, epoch: 1 | loss: 0.6715898
# 	speed: 0.0136s/iter; left time: 6.9271s
# Epoch: 1 cost time: 7.054373264312744
# Epoch: 1, Steps: 455 | Train Loss: 0.6581357 Vali Loss: 1.6777020 Test Loss: 1.6783485
# Validation loss decreased (inf --> 1.677702).  Saving model ...
# Updating learning rate to 0.0005
# 	iters: 100, epoch: 2 | loss: 0.5732089
# 	speed: 0.1635s/iter; left time: 58.2101s
# 	iters: 200, epoch: 2 | loss: 0.5264926
# 	speed: 0.0159s/iter; left time: 4.0697s
# 	iters: 300, epoch: 2 | loss: 0.6817757
# 	speed: 0.0173s/iter; left time: 2.7030s
# 	iters: 400, epoch: 2 | loss: 0.5408267
# 	speed: 0.0168s/iter; left time: 0.9409s
# Epoch: 2 cost time: 8.384399652481079
# Epoch: 2, Steps: 455 | Train Loss: 0.5813841 Vali Loss: 1.4647651 Test Loss: 1.4652163
# Validation loss decreased (1.677702 --> 1.464765).  Saving model ...
# Updating learning rate to 0.00025
# >>>>>>>testing : MSL_ModernTCN_MSL_ftM_dim8_nb1_lk51_sk5_ffr1_ps8_str4_multiFalse_mergedFalse_Exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test: (73729, 55)
# train: (58317, 55)
# test 73634
# test: (73729, 55)
# train: (58317, 55)
# train 58222
# Threshold : 9.882375
# pred:    (7068864,)
# gt:      (7068864,)
# pred:  (7068864,)
# gt:    (7068864,)
# Accuracy : 0.9643, Precision : 0.8958, Recall : 0.7488, F-score : 0.8157

# %% [markdown]
# ### SMAP Dataset

# %%
# !sh ./scripts/SMAP.sh
# Out:
# Args in experiment:
# Namespace(random_seed=2021, is_training=1, model_id='SMAP', model='ModernTCN', data='SMAP', root_path='./all_datasets/SMAP/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', embed='timeF', seq_len=96, label_len=48, pred_len=96, stem_ratio=6, downsample_ratio=2, ffn_ratio=1, patch_size=1, patch_stride=1, num_blocks=[1], large_size=[13], small_size=[5], dims=[128], dw_dims=[256, 256, 256, 256], small_kernel_merged=False, call_structural_reparam=False, use_multi_scale=False, fc_dropout=0.05, head_dropout=0.0, patch_len=16, stride=8, padding_patch='end', revin=1, affine=0, subtract_last=0, decomposition=0, kernel_size=25, individual=0, embed_type=0, enc_in=25, dec_in=7, c_out=25, d_model=512, n_heads=8, e_layers=2, d_layers=1, d_ff=2048, moving_avg=25, factor=1, distil=True, dropout=0.1, activation='gelu', output_attention=False, do_predict=False, num_workers=10, itr=1, train_epochs=1, batch_size=128, patience=10, learning_rate=0.0003, des='Exp', loss='mse', lradj='type1', pct_start=0.3, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', test_flop=False, task_name='anomaly_detection', seasonal_patterns='Monthly', mask_rate=0.25, anomaly_ratio=1.0, class_dropout=0.05)
# Use GPU: cuda:0
# >>>>>>>start training : SMAP_ModernTCN_SMAP_ftM_dim128_nb1_lk13_sk5_ffr1_ps1_str1_multiFalse_mergedFalse_Exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# test: (427617, 25)
# train: (135183, 25)
# train 135088
# test: (427617, 25)
# train: (135183, 25)
# val 427522
# test: (427617, 25)
# train: (135183, 25)
# test 427522
# 	iters: 100, epoch: 1 | loss: 2.1722600
# 	speed: 0.2695s/iter; left time: 257.9365s
# 	iters: 200, epoch: 1 | loss: 1.4914079
# 	speed: 0.2516s/iter; left time: 215.5862s
# 	iters: 300, epoch: 1 | loss: 1.6547048
# 	speed: 0.2517s/iter; left time: 190.5080s
# 	iters: 400, epoch: 1 | loss: 2.9686484
# 	speed: 0.2519s/iter; left time: 165.5230s
# 	iters: 500, epoch: 1 | loss: 1.0728415
# 	speed: 0.2522s/iter; left time: 140.4985s
# 	iters: 600, epoch: 1 | loss: 0.8086526
# 	speed: 0.2523s/iter; left time: 115.2833s
# 	iters: 700, epoch: 1 | loss: 0.5099489
# 	speed: 0.2524s/iter; left time: 90.1232s
# 	iters: 800, epoch: 1 | loss: 0.8877272
# 	speed: 0.2526s/iter; left time: 64.9203s
# 	iters: 900, epoch: 1 | loss: 0.3817863
# 	speed: 0.2529s/iter; left time: 39.7105s
# 	iters: 1000, epoch: 1 | loss: 0.2922626
# 	speed: 0.2540s/iter; left time: 14.4808s
# Epoch: 1 cost time: 267.48546528816223
# Epoch: 1, Steps: 1056 | Train Loss: 1.3111604 Vali Loss: 0.3859505 Test Loss: 0.3859040
# Validation loss decreased (inf --> 0.385950).  Saving model ...
# Updating learning rate to 0.0003
# >>>>>>>testing : SMAP_ModernTCN_SMAP_ftM_dim128_nb1_lk13_sk5_ffr1_ps1_str1_multiFalse_mergedFalse_Exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test: (427617, 25)
# train: (135183, 25)
# test 427522
# test: (427617, 25)
# train: (135183, 25)
# train 135088
# Threshold : 3.2310944
# pred:    (41042112,)
# gt:      (41042112,)
# pred:  (41042112,)
# gt:    (41042112,)
# Accuracy : 0.9364, Precision : 0.9082, Recall : 0.5593, F-score : 0.6923

# %% [markdown]
# ### SWaT Dataset

# %%
# !sh ./scripts/SWaT.sh

# %% [markdown]
# ### PSM Dataset

# %%
# !sh ./scripts/PSM.sh
# Out:
# Args in experiment:
# Namespace(random_seed=2021, is_training=1, model_id='PSM', model='ModernTCN', data='PSM', root_path='./all_datasets/PSM/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', embed='timeF', seq_len=100, label_len=0, pred_len=0, stem_ratio=6, downsample_ratio=2, ffn_ratio=1, patch_size=4, patch_stride=2, num_blocks=[1], large_size=[71], small_size=[5], dims=[256], dw_dims=[256, 256, 256, 256], small_kernel_merged=False, call_structural_reparam=False, use_multi_scale=False, fc_dropout=0.05, head_dropout=0.0, patch_len=16, stride=8, padding_patch='end', revin=1, affine=0, subtract_last=0, decomposition=0, kernel_size=25, individual=0, embed_type=0, enc_in=25, dec_in=7, c_out=25, d_model=512, n_heads=8, e_layers=2, d_layers=1, d_ff=2048, moving_avg=25, factor=1, distil=True, dropout=0.1, activation='gelu', output_attention=False, do_predict=False, num_workers=10, itr=1, train_epochs=2, batch_size=128, patience=10, learning_rate=0.0005, des='Exp', loss='mse', lradj='type1', pct_start=0.3, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', test_flop=False, task_name='anomaly_detection', seasonal_patterns='Monthly', mask_rate=0.25, anomaly_ratio=1.0, class_dropout=0.05)
# Use GPU: cuda:0
# >>>>>>>start training : PSM_ModernTCN_PSM_ftM_dim256_nb1_lk71_sk5_ffr1_ps4_str2_multiFalse_mergedFalse_Exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# test: (87841, 25)
# train: (132481, 25)
# train 132382
# test: (87841, 25)
# train: (132481, 25)
# val 87742
# test: (87841, 25)
# train: (132481, 25)
# test 87742
# 	iters: 100, epoch: 1 | loss: 0.1534034
# 	speed: 0.4879s/iter; left time: 961.6714s
# 	iters: 200, epoch: 1 | loss: 0.1180754
# 	speed: 0.4822s/iter; left time: 902.1347s
# 	iters: 300, epoch: 1 | loss: 0.1273910
# 	speed: 0.4883s/iter; left time: 864.7625s
# 	iters: 400, epoch: 1 | loss: 0.1476196
# 	speed: 0.4887s/iter; left time: 816.6830s
# 	iters: 500, epoch: 1 | loss: 0.0937191
# 	speed: 0.4887s/iter; left time: 767.7078s
# 	iters: 600, epoch: 1 | loss: 0.1017522
# 	speed: 0.4879s/iter; left time: 717.6408s
# 	iters: 700, epoch: 1 | loss: 0.0761223
# 	speed: 0.4876s/iter; left time: 668.5449s
# 	iters: 800, epoch: 1 | loss: 0.0874122
# 	speed: 0.4874s/iter; left time: 619.4501s
# 	iters: 900, epoch: 1 | loss: 0.1210500
# 	speed: 0.4873s/iter; left time: 570.6758s
# 	iters: 1000, epoch: 1 | loss: 0.0988702
# 	speed: 0.4871s/iter; left time: 521.6439s
# Epoch: 1 cost time: 503.312956571579
# Epoch: 1, Steps: 1035 | Train Loss: 0.1144107 Vali Loss: 0.0969758 Test Loss: 0.0970749
# Validation loss decreased (inf --> 0.096976).  Saving model ...
# Updating learning rate to 0.0005
# 	iters: 100, epoch: 2 | loss: 0.0779538
# 	speed: 3.4169s/iter; left time: 3198.2455s
# 	iters: 200, epoch: 2 | loss: 0.0512955
# 	speed: 0.4863s/iter; left time: 406.5695s
# 	iters: 300, epoch: 2 | loss: 0.0590946
# 	speed: 0.4862s/iter; left time: 357.8565s
# 	iters: 400, epoch: 2 | loss: 0.0478723
# 	speed: 0.4862s/iter; left time: 309.2075s
# 	iters: 500, epoch: 2 | loss: 0.0475946
# 	speed: 0.4863s/iter; left time: 260.6489s
# 	iters: 600, epoch: 2 | loss: 0.0540071
# 	speed: 0.4859s/iter; left time: 211.8732s
# 	iters: 700, epoch: 2 | loss: 0.0470355
# 	speed: 0.4860s/iter; left time: 163.2982s
# 	iters: 800, epoch: 2 | loss: 0.0471740
# 	speed: 0.4859s/iter; left time: 114.6784s
# 	iters: 900, epoch: 2 | loss: 0.0482081
# 	speed: 0.4862s/iter; left time: 66.1219s
# 	iters: 1000, epoch: 2 | loss: 0.0389884
# 	speed: 0.4862s/iter; left time: 17.5021s
# Epoch: 2 cost time: 503.3928699493408
# Epoch: 2, Steps: 1035 | Train Loss: 0.0575645 Vali Loss: 0.0496114 Test Loss: 0.0496319
# Validation loss decreased (0.096976 --> 0.049611).  Saving model ...
# Updating learning rate to 0.00025
# >>>>>>>testing : PSM_ModernTCN_PSM_ftM_dim256_nb1_lk71_sk5_ffr1_ps4_str2_multiFalse_mergedFalse_Exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test: (87841, 25)
# train: (132481, 25)
# test 87742
# test: (87841, 25)
# train: (132481, 25)
# train 132382
# Threshold : 0.2499365
# pred:    (8774200,)
# gt:      (8774200,)
# pred:  (8774200,)
# gt:    (8774200,)
# Accuracy : 0.9814, Precision : 0.9864, Recall : 0.9458, F-score : 0.9657

# %% [markdown]
# ## Run ModernTCN on GECCO Dataset

# %%
# --- GECCO anomaly detection (custom hyperparameters) ---
# Uses argv-list subprocess invocation to avoid argparse issues with list-like flags.

from pathlib import Path
import os
import subprocess
import sys
import numpy as np

# Ensure we're in ModernTCN-detection (so relative paths match the repo scripts)
if not Path("run.py").exists():
    os.chdir("/home/fzf/dev/TSAD/ModernTCN/ModernTCN-detection")
assert Path("run.py").exists(), "Couldn't find run.py; please adjust the path in this cell."

gecco_dir = Path("./all_datasets/GECCO")
train_path = gecco_dir / "train.npy"
test_path = gecco_dir / "test.npy"
label_path = gecco_dir / "test_label.npy"
for p in (train_path, test_path, label_path):
    if not p.exists():
        raise FileNotFoundError(f"Missing expected GECCO file: {p.resolve()}")

train = np.load(train_path)
test = np.load(test_path)
labels = np.load(label_path)
assert train.ndim == 2 and test.ndim == 2, f"Expected 2D arrays, got train{train.shape} test{test.shape}"
assert train.shape[1] == test.shape[1], "Train/test feature dims don't match"
enc_in = int(train.shape[1])
print(f"GECCO: train={train.shape}, test={test.shape}, labels={labels.shape}, enc_in={enc_in}")

seed = 2021
run_args = [
    sys.executable, "-u", "run.py",
    "--task_name", "anomaly_detection",
    "--anomaly_ratio", "0.05",
    "--is_training", "1",
    "--root_path", str(gecco_dir) + "/",
    "--model_id", f"GECCO_custom_seed{seed}",
    "--model", "ModernTCN",
    "--seq_len", "100",
    "--label_len", "0",
    "--pred_len", "0",
    "--data", "GECCO",
    "--enc_in", str(enc_in),
    "--c_out", str(enc_in),
    "--ffn_ratio", "1",
    "--patch_size", "8",
    "--patch_stride", "4",
    "--num_blocks", "2",
    "--large_size", "31",
    "--small_size", "5",
    "--dims", "32",
    "--head_dropout", "0.0",
    "--dropout", "0.1",
    "--itr", "1",
    "--learning_rate", "0.0007318393651482247",
    "--batch_size", "128",
    "--train_epochs", "2",
    "--patience", "5",
    "--des", "GECCO_custom",
    "--use_multi_scale", "True",
    "--small_kernel_merged", "False",
    "--random_seed", str(seed),
]
print("Running:\n", " ".join(run_args))
subprocess.run(run_args, check=True)
# Out:
# GECCO: train=(83739, 9), test=(55827, 9), labels=(55827,), enc_in=9
# Running:
#  /home/fzf/.conda/envs/moderntcn/bin/python -u run.py --task_name anomaly_detection --anomaly_ratio 0.05 --is_training 1 --root_path all_datasets/GECCO/ --model_id GECCO_custom_seed2021 --model ModernTCN --seq_len 100 --label_len 0 --pred_len 0 --data GECCO --enc_in 9 --c_out 9 --ffn_ratio 1 --patch_size 8 --patch_stride 4 --num_blocks 2 --large_size 31 --small_size 5 --dims 32 --head_dropout 0.0 --dropout 0.1 --itr 1 --learning_rate 0.0007318393651482247 --batch_size 128 --train_epochs 2 --patience 5 --des GECCO_custom --use_multi_scale True --small_kernel_merged False --random_seed 2021
# Args in experiment:
# Namespace(random_seed=2021, is_training=1, model_id='GECCO_custom_seed2021', model='ModernTCN', data='GECCO', root_path='all_datasets/GECCO/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', embed='timeF', seq_len=100, label_len=0, pred_len=0, stem_ratio=6, downsample_ratio=2, ffn_ratio=1, patch_size=8, patch_stride=4, num_blocks=[2], large_size=[31], small_size=[5], dims=[32], dw_dims=[256, 256, 256, 256], small_kernel_merged=False, call_structural_reparam=False, use_multi_scale=True, fc_dropout=0.05, head_dropout=0.0, patch_len=16, stride=8, padding_patch='end', revin=1, affine=0, subtract_last=0, decomposition=0, kernel_size=25, individual=0, embed_type=0, enc_in=9, dec_in=7, c_out=9, d_model=512, n_heads=8, e_layers=2, d_layers=1, d_ff=2048, moving_avg=25, factor=1, distil=True, dropout=0.1, activation='gelu', output_attention=False, do_predict=False, num_workers=10, itr=1, train_epochs=2, batch_size=128, patience=5, learning_rate=0.0007318393651482247, des='GECCO_custom', loss='mse', lradj='type1', pct_start=0.3, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', test_flop=False, task_name='anomaly_detection', seasonal_patterns='Monthly', mask_rate=0.25, anomaly_ratio=0.05, class_dropout=0.05)
# Use GPU: cuda:0
# >>>>>>>start training : GECCO_custom_seed2021_ModernTCN_GECCO_ftM_dim32_nb2_lk31_sk5_ffr1_ps8_str4_multiTrue_mergedFalse_GECCO_custom_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 837
# val 167
# test 558
# Epoch: 1 cost time: 1.2078144550323486
# Epoch: 1, Steps: 7 | Train Loss: 0.1350366 Vali Loss: 0.0849256 Test Loss: 0.0718954
# Validation loss decreased (inf --> 0.084926).  Saving model ...
# Updating learning rate to 0.0007318393651482247
# Epoch: 2 cost time: 0.469135046005249
# Epoch: 2, Steps: 7 | Train Loss: 0.1301685 Vali Loss: 0.0736289 Test Loss: 0.0696985
# Validation loss decreased (0.084926 --> 0.073629).  Saving model ...
# Updating learning rate to 0.00036591968257411233
# >>>>>>>testing : GECCO_custom_seed2021_ModernTCN_GECCO_ftM_dim32_nb2_lk31_sk5_ffr1_ps8_str4_multiTrue_mergedFalse_GECCO_custom_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 558
# train 837
# Threshold : 27.202833
# pred:    (55800,)
# gt:      (55800,)
# pred:  (55800,)
# gt:    (55800,)
# Accuracy : 0.9968, Precision : 0.9277, Recall : 0.3068, F-score : 0.4611
# GECCO: train=(83739, 9), test=(55827, 9), labels=(55827,), enc_in=9
# Running:
#  /home/fzf/.conda/envs/moderntcn/bin/python -u run.py --task_name anomaly_detection --anomaly_ratio 0.05 --is_training 1 --root_path all_datasets/GECCO/ --model_id GECCO_custom_seed2021 --model ModernTCN --seq_len 100 --label_len 0 --pred_len 0 --data GECCO --enc_in 9 --c_out 9 --ffn_ratio 1 --patch_size 8 --patch_stride 4 --num_blocks 2 --large_size 31 --small_size 5 --dims 32 --head_dropout 0.0 --dropout 0.1 --itr 1 --learning_rate 0.0007318393651482247 --batch_size 128 --train_epochs 2 --patience 5 --des GECCO_custom --use_multi_scale True --small_kernel_merged False --random_seed 2021
# Args in experiment:
# Namespace(random_seed=2021, is_training=1, model_id='GECCO_custom_seed2021', model='ModernTCN', data='GECCO', root_path='all_datasets/GECCO/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', embed='timeF', seq_len=100, label_len=0, pred_len=0, stem_ratio=6, downsample_ratio=2, ffn_ratio=1, patch_size=8, patch_stride=4, num_blocks=[2], large_size=[31], small_size=[5], dims=[32], dw_dims=[256, 256, 256, 256], small_kernel_merged=False, call_structural_reparam=False, use_multi_scale=True, fc_dropout=0.05, head_dropout=0.0, patch_len=16, stride=8, padding_patch='end', revin=1, affine=0, subtract_last=0, decomposition=0, kernel_size=25, individual=0, embed_type=0, enc_in=9, dec_in=7, c_out=9, d_model=512, n_heads=8, e_layers=2, d_layers=1, d_ff=2048, moving_avg=25, factor=1, distil=True, dropout=0.1, activation='gelu', output_attention=False, do_predict=False, num_workers=10, itr=1, train_epochs=2, batch_size=128, patience=5, learning_rate=0.0007318393651482247, des='GECCO_custom', loss='mse', lradj='type1', pct_start=0.3, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', test_flop=False, task_name='anomaly_detection', seasonal_patterns='Monthly', mask_rate=0.25, anomaly_ratio=0.05, class_dropout=0.05)
# Use GPU: cuda:0
# >>>>>>>start training : GECCO_custom_seed2021_ModernTCN_GECCO_ftM_dim32_nb2_lk31_sk5_ffr1_ps8_str4_multiTrue_mergedFalse_GECCO_custom_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 837
# val 167
# test 558
# Epoch: 1 cost time: 1.2078144550323486
# Epoch: 1, Steps: 7 | Train Loss: 0.1350366 Vali Loss: 0.0849256 Test Loss: 0.0718954
# Validation loss decreased (inf --> 0.084926).  Saving model ...
# Updating learning rate to 0.0007318393651482247
# Epoch: 2 cost time: 0.469135046005249
# Epoch: 2, Steps: 7 | Train Loss: 0.1301685 Vali Loss: 0.0736289 Test Loss: 0.0696985
# Validation loss decreased (0.084926 --> 0.073629).  Saving model ...
# Updating learning rate to 0.00036591968257411233
# >>>>>>>testing : GECCO_custom_seed2021_ModernTCN_GECCO_ftM_dim32_nb2_lk31_sk5_ffr1_ps8_str4_multiTrue_mergedFalse_GECCO_custom_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 558
# train 837
# Threshold : 27.202833
# pred:    (55800,)
# gt:      (55800,)
# pred:  (55800,)
# gt:    (55800,)
# Accuracy : 0.9968, Precision : 0.9277, Recall : 0.3068, F-score : 0.4611
# CompletedProcess(args=['/home/fzf/.conda/envs/moderntcn/bin/python', '-u', 'run.py', '--task_name', 'anomaly_detection', '--anomaly_ratio', '0.05', '--is_training', '1', '--root_path', 'all_datasets/GECCO/', '--model_id', 'GECCO_custom_seed2021', '--model', 'ModernTCN', '--seq_len', '100', '--label_len', '0', '--pred_len', '0', '--data', 'GECCO', '--enc_in', '9', '--c_out', '9', '--ffn_ratio', '1', '--patch_size', '8', '--patch_stride', '4', '--num_blocks', '2', '--large_size', '31', '--small_size', '5', '--dims', '32', '--head_dropout', '0.0', '--dropout', '0.1', '--itr', '1', '--learning_rate', '0.0007318393651482247', '--batch_size', '128', '--train_epochs', '2', '--patience', '5', '--des', 'GECCO_custom', '--use_multi_scale', 'True', '--small_kernel_merged', 'False', '--random_seed', '2021'], returncode=0)

# %% [markdown]
# ## Neural Network Intelligence (NNI) toolkit

# %%
# Run NNI from ModernTCN/ (TimesNet-style layout: config + search_space + trial in repo root)
# %cd /home/fzf/dev/TSAD/ModernTCN

# Install NNI if needed
# !python -c "import nni" || pip -q install nni

# Start NNI experiment (UI at http://localhost:8081)
# !nnictl create --config nni_config_moderntcn.yml --port 8081
# Out:
# /home/fzf/dev/TSAD/ModernTCN
# /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages/nni/tools/nnictl/nnictl.py:7: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# [2026-03-24 14:56:34] Creating experiment, Experiment ID: 6xs9cukf
# [2026-03-24 14:56:34] Starting web server...
# [2026-03-24 14:56:35] Setting up...
# [2026-03-24 14:56:35] Web portal URLs: http://127.0.0.1:8081 http://10.28.27.64:8081 http://172.17.0.1:8081
# [2026-03-24 14:56:35] To stop experiment run "nnictl stop 6xs9cukf" or "nnictl stop --all"
# [2026-03-24 14:56:35] Reference: https://nni.readthedocs.io/en/stable/reference/nnictl.html

# %%
# !nnictl stop --all
# Out:
# /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages/nni/tools/nnictl/nnictl.py:7: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# INFO:  Stopping experiment 6xs9cukf
# INFO:  Stop experiment success.

# %%
# !lsof -i :8081

# %%
# !kill -9 1953557

# %% [markdown]
# ## Parameter Count

# %%
# ── Parameter count for ModernTCN (anomaly detection) ───────────────────
import sys, argparse
import torch
import numpy as np

# Assumes you're in ModernTCN-detection (the notebook already does %cd there)
sys.path.insert(0, './')
from models.ModernTCN import Model as ModernTCN

# Hyperparams copied from ModernTCN-detection/scripts/*.sh.
# If a script omits args (e.g. MSL/SMAP), we use run.py defaults (seq_len=96, pred_len=96, label_len=48).
datasets = {
    'SMD':  dict(seq_len=100, label_len=0,  pred_len=0,  enc_in=38, c_out=38, ffn_ratio=1, patch_size=8, patch_stride=4, num_blocks=[1], large_size=[71], small_size=[5], dims=[32],  dropout=0.1, head_dropout=0.0, use_multi_scale=False, small_kernel_merged=False),
    'MSL':  dict(seq_len=96,  label_len=48, pred_len=96, enc_in=55, c_out=55, ffn_ratio=1, patch_size=8, patch_stride=4, num_blocks=[1], large_size=[51], small_size=[5], dims=[8],   dropout=0.1, head_dropout=0.0, use_multi_scale=False, small_kernel_merged=False),
    'SMAP': dict(seq_len=96,  label_len=48, pred_len=96, enc_in=25, c_out=25, ffn_ratio=1, patch_size=1, patch_stride=1, num_blocks=[1], large_size=[13], small_size=[5], dims=[128], dropout=0.1, head_dropout=0.0, use_multi_scale=False, small_kernel_merged=False),
    'SWaT': dict(seq_len=100, label_len=0,  pred_len=0,  enc_in=51, c_out=51, ffn_ratio=1, patch_size=8, patch_stride=4, num_blocks=[3], large_size=[51], small_size=[5], dims=[128], dropout=0.1, head_dropout=0.0, use_multi_scale=False, small_kernel_merged=False),
    'PSM':  dict(seq_len=100, label_len=0,  pred_len=0,  enc_in=25, c_out=25, ffn_ratio=1, patch_size=4, patch_stride=2, num_blocks=[1], large_size=[71], small_size=[5], dims=[256], dropout=0.1, head_dropout=0.0, use_multi_scale=False, small_kernel_merged=False),
    'GECCO':dict(seq_len=100, label_len=0,  pred_len=0,  enc_in=9, c_out=9, ffn_ratio=1, patch_size=8, patch_stride=4, num_blocks=[2], large_size=[31], small_size=[5], dims=[32],  dropout=0.1, head_dropout=0.0, use_multi_scale=True,  small_kernel_merged=False),
}

print(f"{'Dataset':<8} {'Total Params':>14} {'Trainable':>14} {'Non-trainable':>15} {'MB (fp32)':>10}")
print("-" * 67)

for name, hp in datasets.items():
    cfg = argparse.Namespace(
        task_name='anomaly_detection',
        stem_ratio=6, downsample_ratio=2,
        freq='h',
        # misc flags used by the model wrapper
        revin=1, affine=0, subtract_last=0,
        decomposition=0, kernel_size=25, individual=0,
        # keep it consistent with dims:
        dw_dims=hp['dims'],
        **hp,
    )

    model = ModernTCN(cfg).cpu().eval()

    total     = sum(p.numel() for p in model.parameters())
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    frozen    = total - trainable
    mb_fp32   = total * 4 / 1e6  # params * 4 bytes (float32)

    print(f"{name:<8} {total:>14,} {trainable:>14,} {frozen:>15,} {mb_fp32:>10.2f}")
# Out:
# Dataset    Total Params      Trainable   Non-trainable  MB (fp32)
# -------------------------------------------------------------------
# SMD             273,000        273,000               0       1.09
# MSL             102,288        102,288               0       0.41
# SMAP          2,242,785      2,242,785               0       8.97
# SWaT          8,267,400      8,267,400               0      33.07
# PSM           4,137,220      4,137,220               0      16.55
# GECCO            73,256         73,256               0       0.29

# %% [markdown]
# ## Number of Operations

# %%
import warnings
warnings.filterwarnings("ignore", message="Initializing zero-element tensors is a no-op")

# ── Count MACs for ModernTCN (anomaly detection) on ALL datasets ─────────
import sys, argparse
import torch
import torch.nn as nn

# Assumes you're in ModernTCN-detection (the notebook already does %cd there)
sys.path.insert(0, './')
from models.ModernTCN import Model as ModernTCN
from fvcore.nn import FlopCountAnalysis
from thop import profile

class _Wrap(nn.Module):
    def __init__(self, m):
        super().__init__()
        self.inner = m
    def forward(self, x):
        return self.inner(x, None, None, None)

# Best hyperparams per dataset (copied from ModernTCN-detection/scripts/*.sh).
# If a script omits args (e.g. MSL/SMAP), we use run.py defaults (seq_len=96, pred_len=96, label_len=48).
datasets = {
    'SMD':  dict(seq_len=100, label_len=0,  pred_len=0,  enc_in=38, c_out=38, ffn_ratio=1, patch_size=8, patch_stride=4, num_blocks=[1], large_size=[71], small_size=[5], dims=[32],  dropout=0.1, head_dropout=0.0, use_multi_scale=False, small_kernel_merged=False),
    'MSL':  dict(seq_len=96,  label_len=48, pred_len=96, enc_in=55, c_out=55, ffn_ratio=1, patch_size=8, patch_stride=4, num_blocks=[1], large_size=[51], small_size=[5], dims=[8],   dropout=0.1, head_dropout=0.0, use_multi_scale=False, small_kernel_merged=False),
    'SMAP': dict(seq_len=96,  label_len=48, pred_len=96, enc_in=25, c_out=25, ffn_ratio=1, patch_size=1, patch_stride=1, num_blocks=[1], large_size=[13], small_size=[5], dims=[128], dropout=0.1, head_dropout=0.0, use_multi_scale=False, small_kernel_merged=False),
    'SWaT': dict(seq_len=100, label_len=0,  pred_len=0,  enc_in=51, c_out=51, ffn_ratio=1, patch_size=8, patch_stride=4, num_blocks=[3], large_size=[51], small_size=[5], dims=[128], dropout=0.1, head_dropout=0.0, use_multi_scale=False, small_kernel_merged=False),
    'PSM':  dict(seq_len=100, label_len=0,  pred_len=0,  enc_in=25, c_out=25, ffn_ratio=1, patch_size=4, patch_stride=2, num_blocks=[1], large_size=[71], small_size=[5], dims=[256], dropout=0.1, head_dropout=0.0, use_multi_scale=False, small_kernel_merged=False),
    'GECCO':dict(seq_len=100, label_len=0,  pred_len=0,  enc_in=9, c_out=9, ffn_ratio=1, patch_size=8, patch_stride=4, num_blocks=[2], large_size=[31], small_size=[5], dims=[32],  dropout=0.1, head_dropout=0.0, use_multi_scale=True,  small_kernel_merged=False),
}

print(f"{'Dataset':<8} {'fvcore MACs':>14} {'thop MACs':>14} {'Diff%':>10}")
print("-" * 50)

for name, hp in datasets.items():
    cfg = argparse.Namespace(
        task_name='anomaly_detection',
        stem_ratio=6, downsample_ratio=2,
        freq='h',
        # misc flags used by the model wrapper
        revin=1, affine=0, subtract_last=0,
        decomposition=0, kernel_size=25, individual=0,
        # keep it consistent with dims:
        dw_dims=hp['dims'],
        **hp,
    )
    model = ModernTCN(cfg).cpu().eval()
    wrapped = _Wrap(model)
    torch.manual_seed(42)
    dummy = torch.randn(1, cfg.seq_len, cfg.enc_in)

    with torch.no_grad():
        # fvcore
        fa = FlopCountAnalysis(wrapped, dummy)
        fa.unsupported_ops_warnings(False)
        fa.uncalled_modules_warnings(False)
        fvcore_macs = fa.total()

        # thop
        thop_macs, _ = profile(wrapped, inputs=(dummy,), verbose=False)

    diff_pct = abs(fvcore_macs - thop_macs) / max(fvcore_macs, 1) * 100
    print(f"{name:<8} {fvcore_macs:>14,} {thop_macs:>14,.0f} {diff_pct:>9.4f}%")
# Out:
# Dataset     fvcore MACs      thop MACs      Diff%
# --------------------------------------------------
# SMD           7,235,200      7,417,600    2.5210%
# MSL           2,154,240      2,217,600    2.9412%
# SMAP        101,990,400    103,833,600    1.8072%
# SWaT        208,243,200    211,180,800    1.4107%
# PSM         208,640,000    210,560,000    0.9202%
# GECCO         1,900,800      1,987,200    4.5455%

# %% [markdown]
# ### Normalizing for streaming data

# %%
import warnings
warnings.filterwarnings("ignore", message="Initializing zero-element tensors is a no-op")

# ── Count MACs for ModernTCN on ALL datasets (normalized for streaming) ───
import sys, argparse
import torch
import torch.nn as nn

# Assumes you're in ModernTCN-detection (the notebook already does %cd there)
sys.path.insert(0, './')
from models.ModernTCN import Model as ModernTCN
from fvcore.nn import FlopCountAnalysis
from thop import profile

class _Wrap(nn.Module):
    def __init__(self, m):
        super().__init__()
        self.inner = m
    def forward(self, x):
        return self.inner(x, None, None, None)

# Best hyperparams per dataset (copied from ModernTCN-detection/scripts/*.sh).
# If a script omits args (e.g. MSL/SMAP), we use run.py defaults (seq_len=96, pred_len=96, label_len=48).
datasets = {
    'SMD':  dict(seq_len=100, label_len=0,  pred_len=0,  enc_in=38, c_out=38, ffn_ratio=1, patch_size=8, patch_stride=4, num_blocks=[1], large_size=[71], small_size=[5], dims=[32],  dropout=0.1, head_dropout=0.0, use_multi_scale=False, small_kernel_merged=False),
    'MSL':  dict(seq_len=96,  label_len=48, pred_len=96, enc_in=55, c_out=55, ffn_ratio=1, patch_size=8, patch_stride=4, num_blocks=[1], large_size=[51], small_size=[5], dims=[8],   dropout=0.1, head_dropout=0.0, use_multi_scale=False, small_kernel_merged=False),
    'SMAP': dict(seq_len=96,  label_len=48, pred_len=96, enc_in=25, c_out=25, ffn_ratio=1, patch_size=1, patch_stride=1, num_blocks=[1], large_size=[13], small_size=[5], dims=[128], dropout=0.1, head_dropout=0.0, use_multi_scale=False, small_kernel_merged=False),
    'SWaT': dict(seq_len=100, label_len=0,  pred_len=0,  enc_in=51, c_out=51, ffn_ratio=1, patch_size=8, patch_stride=4, num_blocks=[3], large_size=[51], small_size=[5], dims=[128], dropout=0.1, head_dropout=0.0, use_multi_scale=False, small_kernel_merged=False),
    'PSM':  dict(seq_len=100, label_len=0,  pred_len=0,  enc_in=25, c_out=25, ffn_ratio=1, patch_size=4, patch_stride=2, num_blocks=[1], large_size=[71], small_size=[5], dims=[256], dropout=0.1, head_dropout=0.0, use_multi_scale=False, small_kernel_merged=False),
    'GECCO':dict(seq_len=100, label_len=0,  pred_len=0,  enc_in=9, c_out=9, ffn_ratio=1, patch_size=8, patch_stride=4, num_blocks=[2], large_size=[31], small_size=[5], dims=[32],  dropout=0.1, head_dropout=0.0, use_multi_scale=True,  small_kernel_merged=False),
}

print(
    f"{'Dataset':<8} {'seq_len':>8}  "
    f"{'fvcore/sample':>22} {'fvcore/t-point':>22}  "
    f"{'thop/sample':>22} {'thop/t-point':>22}"
)
print("-" * 115)

for name, hp in datasets.items():
    cfg = argparse.Namespace(
        task_name='anomaly_detection',
        stem_ratio=6, downsample_ratio=2,
        freq='h',
        # misc flags used by the model wrapper
        revin=1, affine=0, subtract_last=0,
        decomposition=0, kernel_size=25, individual=0,
        # keep it consistent with dims:
        dw_dims=hp['dims'],
        **hp,
    )
    model   = ModernTCN(cfg).cpu().eval()
    wrapped = _Wrap(model)
    torch.manual_seed(42)

    dummy = torch.randn(1, cfg.seq_len, cfg.enc_in)

    with torch.no_grad():
        fa = FlopCountAnalysis(wrapped, dummy)
        fa.unsupported_ops_warnings(False)
        fa.uncalled_modules_warnings(False)
        fvcore_sample = fa.total()

        thop_sample, _ = profile(wrapped, inputs=(dummy,), verbose=False)

    # Per time point = per sample ÷ seq_len
    # In streaming mode: one forward pass covers seq_len points
    # but only 1 new point arrives — so seq_len-1 points are redundantly recomputed
    fvcore_timepoint = fvcore_sample / cfg.seq_len
    thop_timepoint   = thop_sample   / cfg.seq_len

    print(
        f"{name:<8} {cfg.seq_len:>8}  "
        f"{fvcore_sample:>22,} {int(fvcore_timepoint):>22,}  "
        f"{int(thop_sample):>22,} {int(thop_timepoint):>22,}"
    )

print()
print("Columns:")
print("  fvcore/sample  = MACs to process one full sliding window (fvcore)")
print("  fvcore/t-point = effective MACs per new arriving time point (fvcore)")
print("  thop/sample    = MACs to process one full sliding window (thop)")
print("  thop/t-point   = effective MACs per new arriving time point (thop)")
print("  t-point        = MACs/sample ÷ seq_len")
# Out:
# Dataset   seq_len           fvcore/sample         fvcore/t-point             thop/sample           thop/t-point
# -------------------------------------------------------------------------------------------------------------------
# SMD           100               7,235,200                 72,352               7,417,600                 74,176
# MSL            96               2,154,240                 22,440               2,217,600                 23,100
# SMAP           96             101,990,400              1,062,400             103,833,600              1,081,600
# SWaT          100             208,243,200              2,082,432             211,180,800              2,111,808
# PSM           100             208,640,000              2,086,400             210,560,000              2,105,600
# GECCO         100               1,900,800                 19,008               1,987,200                 19,872
#
# Columns:
#   fvcore/sample  = MACs to process one full sliding window (fvcore)
#   fvcore/t-point = effective MACs per new arriving time point (fvcore)
#   thop/sample    = MACs to process one full sliding window (thop)
#   thop/t-point   = effective MACs per new arriving time point (thop)
#   t-point        = MACs/sample ÷ seq_len

# %% [markdown]
# ## Memory Usage

# %%
# ── Memory usage for ModernTCN Anomaly Detection (batch_size=128) ─────────
import os, sys, argparse
import numpy as np
import torch
import torch.nn as nn

# Assumes you're in ModernTCN-detection (the notebook already does %cd there)
sys.path.insert(0, "./")

# IMPORTANT: set this BEFORE the first torch.cuda call.
# This mirrors the TimesNet notebook: exposing physical GPU "3" as cuda:0.
os.environ["CUDA_VISIBLE_DEVICES"] = "3"  # change if needed

from exp.exp_anomaly_detection import Exp_Anomaly_Detection

if not torch.cuda.is_available():
    raise RuntimeError("CUDA is not available. Run this cell on a GPU machine or switch to a CUDA-enabled PyTorch install.")

# ── Force CUDA initialization ───────────────────────────────────────────
_ = torch.zeros(1).cuda()
device = torch.device("cuda:0")
print(f"Using device: {torch.cuda.get_device_name(0)}")

# GECCO feature dimension (enc_in/c_out) inferred from dataset files
gecco_enc_in = int(np.load('./all_datasets/GECCO/train.npy').shape[1])

# ── Dataset configurations (best hyperparams from your runs) ─────────────
# Hyperparams copied from ModernTCN-detection/scripts/*.sh.
# If a script omits args (e.g. MSL/SMAP), we use run.py defaults (seq_len=96, pred_len=96, label_len=48).
DATASETS = {
    "SMD": dict(
        model_id="SMD", data="SMD",
        root_path="./all_datasets/SMD/",
        seq_len=100, label_len=0, pred_len=0,
        enc_in=38, c_out=38,
        ffn_ratio=1, patch_size=8, patch_stride=4,
        num_blocks=[1], large_size=[71], small_size=[5], dims=[32],
        dropout=0.1, head_dropout=0.0,
        use_multi_scale=False, small_kernel_merged=False,
        anomaly_ratio=0.5,
    ),
    "MSL": dict(
        model_id="MSL", data="MSL",
        root_path="./all_datasets/MSL/",
        enc_in=55, c_out=55,
        ffn_ratio=1, patch_size=8, patch_stride=4,
        num_blocks=[1], large_size=[51], small_size=[5], dims=[8],
        dropout=0.1, head_dropout=0.0,
        use_multi_scale=False, small_kernel_merged=False,
        anomaly_ratio=1.0,
    ),
    "SMAP": dict(
        model_id="SMAP", data="SMAP",
        root_path="./all_datasets/SMAP/",
        enc_in=25, c_out=25,
        ffn_ratio=1, patch_size=1, patch_stride=1,
        num_blocks=[1], large_size=[13], small_size=[5], dims=[128],
        dropout=0.1, head_dropout=0.0,
        use_multi_scale=False, small_kernel_merged=False,
        anomaly_ratio=1.0,
    ),
    "SWaT": dict(
        model_id="SWAT", data="SWAT",
        root_path="./all_datasets/SWaT/",
        seq_len=100, label_len=0, pred_len=0,
        enc_in=51, c_out=51,
        ffn_ratio=1, patch_size=8, patch_stride=4,
        num_blocks=[3], large_size=[51], small_size=[5], dims=[128],
        dropout=0.1, head_dropout=0.0,
        use_multi_scale=False, small_kernel_merged=False,
        anomaly_ratio=0.5,
    ),
    "PSM": dict(
        model_id="PSM", data="PSM",
        root_path="./all_datasets/PSM/",
        seq_len=100, label_len=0, pred_len=0,
        enc_in=25, c_out=25,
        ffn_ratio=1, patch_size=4, patch_stride=2,
        num_blocks=[1], large_size=[71], small_size=[5], dims=[256],
        dropout=0.1, head_dropout=0.0,
        use_multi_scale=False, small_kernel_merged=False,
        anomaly_ratio=1.0,
    ),
    "GECCO": dict(
        model_id="GECCO", data="GECCO",
        root_path="./all_datasets/GECCO/",
        seq_len=100, label_len=0, pred_len=0,
        enc_in=gecco_enc_in, c_out=gecco_enc_in,
        ffn_ratio=1, patch_size=8, patch_stride=4,
        num_blocks=[2], large_size=[31], small_size=[5], dims=[32],
        dropout=0.1, head_dropout=0.0,
        use_multi_scale=True, small_kernel_merged=False,
        anomaly_ratio=0.05,
    ),
}

# ── Fixed args shared across all datasets ───────────────────────────────
BASE_ARGS = dict(
    task_name="anomaly_detection",
    is_training=0,
    model="ModernTCN",
    features="M", target="OT", freq="h", embed="timeF",
    checkpoints="./checkpoints/",
    # run.py defaults used when scripts omit values
    seq_len=96, label_len=48, pred_len=96,
    stem_ratio=6, downsample_ratio=2,
    ffn_ratio=2, patch_size=16, patch_stride=8,
    num_blocks=[1, 1, 1, 1],
    large_size=[31, 29, 27, 13],
    small_size=[5, 5, 5, 5],
    dims=[256, 256, 256, 256],
    dw_dims=[256, 256, 256, 256],
    small_kernel_merged=False,
    use_multi_scale=True,
    call_structural_reparam=False,
    # misc flags used by model wrapper
    revin=1, affine=0, subtract_last=0,
    decomposition=0, kernel_size=25, individual=0,
    dropout=0.1, head_dropout=0.0, fc_dropout=0.05,
    # optimization (only used for training; still needed for Exp to exist)
    batch_size=128, train_epochs=1, patience=10, learning_rate=0.0005,
    pct_start=0.3, lradj="type1", loss="mse", use_amp=False,
    num_workers=10, itr=1, des="Exp",
    # GPU
    use_gpu=True, gpu=0, use_multi_gpu=False, devices="0,1,2,3",
)

# ── Measure memory for each dataset ─────────────────────────────────────
results = {}

for dataset_name, ds_args in DATASETS.items():
    print(f"Measuring {dataset_name}...")
    try:
        # Build args
        args_dict = {**BASE_ARGS, **ds_args}
        # Keep dw_dims consistent with dims when overridden
        args_dict["dw_dims"] = list(args_dict["dims"])
        args = argparse.Namespace(**args_dict)

        # Clear GPU memory from previous iteration
        torch.cuda.empty_cache()
        torch.cuda.reset_peak_memory_stats(device)
        baseline = torch.cuda.memory_allocated(device)

        # Load model on GPU via the repo's experiment wrapper
        exp = Exp_Anomaly_Detection(args)
        model = exp.model
        weight_mem = (torch.cuda.memory_allocated(device) - baseline) / 1e6

        # Dummy input matching dataset dimensions
        dummy = torch.randn(args.batch_size, args.seq_len, args.enc_in, device=device)
        criterion = nn.MSELoss()

        # Peak training memory (forward + backward)
        model.train()
        model.zero_grad(set_to_none=True)
        torch.cuda.reset_peak_memory_stats(device)
        output = model(dummy, None, None, None)
        loss = criterion(output, dummy)
        loss.backward()
        peak_train = torch.cuda.max_memory_allocated(device) / 1e6

        # Peak inference memory (no gradients)
        model.eval()
        torch.cuda.reset_peak_memory_stats(device)
        with torch.no_grad():
            _ = model(dummy, None, None, None)
        peak_infer = torch.cuda.max_memory_allocated(device) / 1e6

        total_params = sum(p.numel() for p in model.parameters())

        results[dataset_name] = {
            "params":       total_params,
            "weight_exact": total_params * 4 / 1e6,  # params × 4 bytes → MB
            "weight_mb":    weight_mem,              # allocated after model init (includes buffers)
            "train_mb":     peak_train,
            "infer_mb":     peak_infer,
            "overhead_mb":  peak_train - weight_mem,
        }

        # Clean up before next dataset
        del model, exp, dummy, output, loss
        torch.cuda.empty_cache()

    except Exception as e:
        print(f"  ERROR: {e}")
        results[dataset_name] = None

# ── Print summary table ────────────────────────────────────────────────
print("\n" + "=" * 95)
print("MEMORY SUMMARY — ModernTCN Anomaly Detection (batch_size=128)")
print("=" * 95)
print(f"{'Dataset':<8} {'Params':<12} {'Weights exact':<15} {'Weights GPU':<13} "
      f"{'Train peak':<13} {'Infer peak':<13} {'Overhead':<10}")
print(f"{'':>20} {'(params×4B)':>15} {'(allocated)':>13} "
      f"{'(MB)':>13} {'(MB)':>13} {'(MB)':>10}")
print("-" * 95)
for name, r in results.items():
    if r is None:
        print(f"{name:<8} ERROR")
    else:
        print(f"{name:<8} {r['params']:>10,}   {r['weight_exact']:>11.2f} MB  "
              f"{r['weight_mb']:>9.2f} MB  "
              f"{r['train_mb']:>9.2f} MB  "
              f"{r['infer_mb']:>9.2f} MB  "
              f"{r['overhead_mb']:>7.2f} MB")
# Out:
# Using device: NVIDIA GeForce RTX 2080
# Measuring SMD...
# Use GPU: cuda:0
# Measuring MSL...
# Use GPU: cuda:0
# Measuring SMAP...
# Use GPU: cuda:0
# Measuring SWaT...
# Use GPU: cuda:0
# Measuring PSM...
# Use GPU: cuda:0
# Measuring GECCO...
# Use GPU: cuda:0
#
# ===============================================================================================
# MEMORY SUMMARY — ModernTCN Anomaly Detection (batch_size=128)
# ===============================================================================================
# Dataset  Params       Weights exact   Weights GPU   Train peak    Infer peak    Overhead
#                          (params×4B)   (allocated)          (MB)          (MB)       (MB)
# -----------------------------------------------------------------------------------------------
# SMD         273,000          1.09 MB       1.12 MB     246.56 MB     105.68 MB   245.44 MB
# MSL         102,288          0.41 MB       0.43 MB     111.07 MB      59.60 MB   110.64 MB
# SMAP      2,242,785          8.97 MB       9.81 MB    2239.35 MB     825.98 MB  2229.54 MB
# SWaT      8,267,400         33.07 MB      34.09 MB    3168.24 MB     601.86 MB  3134.15 MB
# PSM       4,137,220         16.55 MB      17.26 MB    2337.98 MB     878.63 MB  2320.72 MB
# GECCO        73,256          0.29 MB       0.32 MB     117.77 MB      44.33 MB   117.44 MB

# %% [markdown]
# ## Inference Speed
#
# Measures latency, throughput, and s/iter for each dataset using CUDA Events.
# - **Latency**: time to process one batch (ms)
# - **Throughput**: samples processed per second
# - **s/iter**: latency in seconds — comparable to paper Table 11 (Wu et al., 2023)

# %%
# ── Inference speed for ModernTCN on ALL datasets (CUDA Events) ───────────
import torch
import argparse
import numpy as np
import sys
import os

# Assumes you're in ModernTCN-detection (the notebook already does %cd there)
sys.path.insert(0, './')

from exp.exp_anomaly_detection import Exp_Anomaly_Detection

# Reuse DATASETS/BASE_ARGS from the Memory Usage cell above
if 'DATASETS' not in globals() or 'BASE_ARGS' not in globals():
    raise RuntimeError("Run the Memory Usage cell first (it defines DATASETS and BASE_ARGS).")

# Use the same device already initialized above if available
device = globals().get('device', torch.device('cuda:0'))
if not torch.cuda.is_available():
    raise RuntimeError('CUDA is not available.')
print(f"Using device: {torch.cuda.get_device_name(0)}")

N_WARMUP = 10
N_RUNS   = 100

# ── Measure each dataset ──────────────────────────────────────────────
speed_results = {}

for dataset_name, ds_args in DATASETS.items():
    print(f"Measuring {dataset_name}...", end=" ", flush=True)
    try:
        # Build args (and keep dw_dims consistent with dims when overridden)
        args_dict = {**BASE_ARGS, **ds_args}
        args_dict['dw_dims'] = list(args_dict['dims'])
        args = argparse.Namespace(**args_dict)

        torch.cuda.empty_cache()
        exp   = Exp_Anomaly_Detection(args)
        model = exp.model
        model.eval()

        dummy = torch.randn(args.batch_size, args.seq_len, args.enc_in, device=device)

        # Warmup: GPU needs a few passes to reach steady state
        with torch.no_grad():
            for _ in range(N_WARMUP):
                _ = model(dummy, None, None, None)

        # Measure using CUDA Events (GPU-side timestamps, not CPU timer)
        times_ms = []
        with torch.no_grad():
            for _ in range(N_RUNS):
                start = torch.cuda.Event(enable_timing=True)
                end   = torch.cuda.Event(enable_timing=True)
                torch.cuda.synchronize()
                start.record()
                _ = model(dummy, None, None, None)
                end.record()
                torch.cuda.synchronize()
                times_ms.append(start.elapsed_time(end))

        times_ms = np.asarray(times_ms, dtype=np.float64)

        speed_results[dataset_name] = {
            'latency_mean_ms': float(times_ms.mean()),
            'latency_std_ms':  float(times_ms.std(ddof=0)),
            'latency_min_ms':  float(times_ms.min()),
            'latency_max_ms':  float(times_ms.max()),
            'throughput':      float(args.batch_size / (times_ms.mean() / 1000.0)),
            's_per_iter':      float(times_ms.mean() / 1000.0),
            'seq_len':         int(args.seq_len),
            'enc_in':          int(args.enc_in),
            'batch_size':      int(args.batch_size),
        }
        print(f"done ({times_ms.mean():.2f} ms)")

        del model, exp, dummy
        torch.cuda.empty_cache()

    except Exception as e:
        print(f"ERROR: {e}")
        speed_results[dataset_name] = None

# ── Print summary table ────────────────────────────────────────────────
print("" + "=" * 98)
print(f"INFERENCE SPEED SUMMARY — ModernTCN Anomaly Detection (batch_size={BASE_ARGS.get('batch_size', 'NA')}, N={N_RUNS} runs)")
print("=" * 98)
print(f"{'Dataset':<8} {'seq_len':<9} {'enc_in':<8} {'B':<4} {'Latency mean±std (ms)':<26} {'Throughput (samp/s)':<22} {'s/iter'}")
print("-" * 98)
for name, r in speed_results.items():
    if r is None:
        print(f"{name:<8} ERROR")
    else:
        lat = f"{r['latency_mean_ms']:.3f} ± {r['latency_std_ms']:.3f}"
        print(f"{name:<8} {r['seq_len']:<9} {r['enc_in']:<8} {r['batch_size']:<4} {lat:<26} {r['throughput']:>18,.1f}     {r['s_per_iter']:.4f}")
# Out:
# Using device: NVIDIA GeForce RTX 2080
# Measuring SMD... Use GPU: cuda:0
# done (3.65 ms)
# Measuring MSL... Use GPU: cuda:0
# done (2.87 ms)
# Measuring SMAP... Use GPU: cuda:0
# done (23.74 ms)
# Measuring SWaT... Use GPU: cuda:0
# done (44.39 ms)
# Measuring PSM... Use GPU: cuda:0
# done (193.50 ms)
# Measuring GECCO... Use GPU: cuda:0
# done (9.41 ms)
# ==================================================================================================
# INFERENCE SPEED SUMMARY — ModernTCN Anomaly Detection (batch_size=128, N=100 runs)
# ==================================================================================================
# Dataset  seq_len   enc_in   B    Latency mean±std (ms)      Throughput (samp/s)    s/iter
# --------------------------------------------------------------------------------------------------
# SMD      100       38       128  3.654 ± 0.244                        35,030.2     0.0037
# MSL      96        55       128  2.871 ± 0.072                        44,581.7     0.0029
# SMAP     96        25       128  23.739 ± 0.030                        5,391.9     0.0237
# SWaT     100       51       128  44.394 ± 0.126                        2,883.3     0.0444
# PSM      100       25       128  193.497 ± 0.225                         661.5     0.1935
# GECCO    100       9        128  9.409 ± 0.124                        13,603.3     0.0094
