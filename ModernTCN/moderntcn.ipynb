# %% [markdown]
# # ModernTCN

# %% [markdown]
# ## Setup Conda Environment (First Time Only)
#
# Run this in a terminal once to create the environment:

# %%
# Create conda environment (only run once)
# !conda create -n moderntcn python=3.9 -y

# %% [markdown]
# Now you can choose the newly created env as a runtime for this notebook, so you can run the following cells in the notebook.

# %%
# Register environment as Jupyter kernel (only run once)
# !conda run -n moderntcn pip install ipykernel
# !conda run -n moderntcn python -m ipykernel install --user --name=moderntcn --display-name "Python (moderntcn)"

# %% [markdown]
# ### Navigate to Project Directory

# %%
# %cd /home/fzf/dev/TSAD/ModernTCN/ModernTCN-detection
# Out:
# /home/fzf/dev/TSAD/ModernTCN

# %% [markdown]
# ### Install Dependencies

# %%
# Verify we're using the correct environment
import sys
print(f"Python path: {sys.executable}")
# Out:
# Python path: /home/fzf/.conda/envs/moderntcn/bin/python

# %%
# Install requirements
# !pip install -r requirements.txt

# Needed for the "Number of Operations" (MACs) section
# !pip install fvcore thop

# %% [markdown]
# ## Run ModernTCN

# %% [markdown]
# Check GPU Availability

# %%
# !nvidia-smi

# %% [markdown]
# Select booked GPU

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '2'

# %% [markdown]
# ### SMD Dataset

# %%
# !python -u run.py \
  --task_name anomaly_detection \
  --anomaly_ratio 0.5 \
  --is_training 0 \
  --root_path ./all_datasets/SMD/ \
  --model_id SMD \
  --model ModernTCN \
  --seq_len 100 \
  --label_len 0 \
  --pred_len 0 \
  --data SMD \
  --enc_in 38 \
  --c_out 38 \
  --ffn_ratio 1 \
  --patch_size 8 \
  --patch_stride 4 \
  --num_blocks 1 \
  --large_size 51 \
  --small_size 5 \
  --dims 64 \
  --head_dropout 0.0 \
  --dropout 0.1 \
  --itr 1 \
  --learning_rate 0.0003 \
  --batch_size 128 \
  --train_epochs 10 \
  --patience 3 \
  --des Exp \
  --use_multi_scale False \
  --small_kernel_merged False
# Out:
# Args in experiment:
# Namespace(random_seed=2021, is_training=0, model_id='SMD', model='ModernTCN', data='SMD', root_path='./all_datasets/SMD/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', embed='timeF', seq_len=100, label_len=0, pred_len=0, stem_ratio=6, downsample_ratio=2, ffn_ratio=1, patch_size=8, patch_stride=4, num_blocks=[1], large_size=[51], small_size=[5], dims=[64], dw_dims=[256, 256, 256, 256], small_kernel_merged=False, call_structural_reparam=False, use_multi_scale=False, fc_dropout=0.05, head_dropout=0.0, patch_len=16, stride=8, padding_patch='end', revin=1, affine=0, subtract_last=0, decomposition=0, kernel_size=25, individual=0, embed_type=0, enc_in=38, dec_in=7, c_out=38, d_model=512, n_heads=8, e_layers=2, d_layers=1, d_ff=2048, moving_avg=25, factor=1, distil=True, dropout=0.1, activation='gelu', output_attention=False, do_predict=False, num_workers=10, itr=1, train_epochs=10, batch_size=128, patience=3, learning_rate=0.0003, des='Exp', loss='mse', lradj='type1', pct_start=0.3, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', test_flop=False, task_name='anomaly_detection', seasonal_patterns='Monthly', mask_rate=0.25, anomaly_ratio=0.5, class_dropout=0.05)
# Use GPU: cuda:0
# >>>>>>>testing : SMD_ModernTCN_SMD_ftM_dim64_nb1_lk51_sk5_ffr1_ps8_str4_multiFalse_mergedFalse_Exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 7084
# train 7084
# loading model
# Threshold : 4.808077
# pred:    (708400,)
# gt:      (708400,)
# Saved test_input/output (53.8 MB each, float16, sub=1)
# pred:  (708400,)
# gt:    (708400,)
# Accuracy : 0.9867, Precision : 0.8684, Recall : 0.8001, F-score : 0.8328, AUC : 0.7296, AU-PR : 0.1420

# %% [markdown]
# ### MSL Dataset

# %%
# !python -u run.py \
  --task_name anomaly_detection \
  --anomaly_ratio 1 \
  --is_training 0 \
  --root_path ./all_datasets/MSL/ \
  --model_id MSL \
  --model ModernTCN \
  --data MSL \
  --enc_in 55 \
  --c_out 55 \
  --ffn_ratio 1 \
  --patch_size 8 \
  --patch_stride 4 \
  --num_blocks 1 \
  --large_size 51 \
  --small_size 5 \
  --dims 64 \
  --head_dropout 0.0 \
  --dropout 0.1 \
  --itr 1 \
  --learning_rate 0.0003 \
  --batch_size 128 \
  --train_epochs 10 \
  --patience 3 \
  --des Exp \
  --use_multi_scale False \
  --small_kernel_merged False
# Out:
# Args in experiment:
# Namespace(random_seed=2021, is_training=0, model_id='MSL', model='ModernTCN', data='MSL', root_path='./all_datasets/MSL/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', embed='timeF', seq_len=96, label_len=48, pred_len=96, stem_ratio=6, downsample_ratio=2, ffn_ratio=1, patch_size=8, patch_stride=4, num_blocks=[1], large_size=[51], small_size=[5], dims=[64], dw_dims=[256, 256, 256, 256], small_kernel_merged=False, call_structural_reparam=False, use_multi_scale=False, fc_dropout=0.05, head_dropout=0.0, patch_len=16, stride=8, padding_patch='end', revin=1, affine=0, subtract_last=0, decomposition=0, kernel_size=25, individual=0, embed_type=0, enc_in=55, dec_in=7, c_out=55, d_model=512, n_heads=8, e_layers=2, d_layers=1, d_ff=2048, moving_avg=25, factor=1, distil=True, dropout=0.1, activation='gelu', output_attention=False, do_predict=False, num_workers=10, itr=1, train_epochs=10, batch_size=128, patience=3, learning_rate=0.0003, des='Exp', loss='mse', lradj='type1', pct_start=0.3, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', test_flop=False, task_name='anomaly_detection', seasonal_patterns='Monthly', mask_rate=0.25, anomaly_ratio=1.0, class_dropout=0.05)
# Use GPU: cuda:0
# >>>>>>>testing : MSL_ModernTCN_MSL_ftM_dim64_nb1_lk51_sk5_ffr1_ps8_str4_multiFalse_mergedFalse_Exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test: (73729, 55)
# train: (58317, 55)
# test 73634
# test: (73729, 55)
# train: (58317, 55)
# train 58222
# loading model
# Threshold : 8.573425
# pred:    (7068864,)
# gt:      (7068864,)
# Saved test_input/output (8.1 MB each, float16, sub=96)
# Saved raw scores and labels for PR curve (MSL)
# pred:  (7068864,)
# gt:    (7068864,)
# Accuracy : 0.9641, Precision : 0.8939, Recall : 0.7480, F-score : 0.8145, AUC : 0.6146, AU-PR : 0.1408

# %% [markdown]
# ### SMAP Dataset

# %%
# !python -u run.py \
  --task_name anomaly_detection \
  --anomaly_ratio 1 \
  --is_training 1 \
  --root_path ./all_datasets/SMAP/ \
  --model_id SMAP \
  --model ModernTCN \
  --data SMAP \
  --enc_in 25 \
  --c_out 25 \
  --ffn_ratio 1 \
  --patch_size 8 \
  --patch_stride 4 \
  --num_blocks 1 \
  --large_size 51 \
  --small_size 5 \
  --dims 32 \
  --head_dropout 0.0 \
  --dropout 0.1 \
  --itr 1 \
  --learning_rate 0.0003 \
  --batch_size 128 \
  --train_epochs 10 \
  --patience 3 \
  --des Exp \
  --use_multi_scale False \
  --small_kernel_merged False
# Out:
# Args in experiment:
# Namespace(random_seed=2021, is_training=0, model_id='SMAP', model='ModernTCN', data='SMAP', root_path='./all_datasets/SMAP/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', embed='timeF', seq_len=96, label_len=48, pred_len=96, stem_ratio=6, downsample_ratio=2, ffn_ratio=1, patch_size=8, patch_stride=4, num_blocks=[1], large_size=[51], small_size=[5], dims=[32], dw_dims=[256, 256, 256, 256], small_kernel_merged=False, call_structural_reparam=False, use_multi_scale=False, fc_dropout=0.05, head_dropout=0.0, patch_len=16, stride=8, padding_patch='end', revin=1, affine=0, subtract_last=0, decomposition=0, kernel_size=25, individual=0, embed_type=0, enc_in=25, dec_in=7, c_out=25, d_model=512, n_heads=8, e_layers=2, d_layers=1, d_ff=2048, moving_avg=25, factor=1, distil=True, dropout=0.1, activation='gelu', output_attention=False, do_predict=False, num_workers=10, itr=1, train_epochs=10, batch_size=128, patience=3, learning_rate=0.0003, des='Exp', loss='mse', lradj='type1', pct_start=0.3, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', test_flop=False, task_name='anomaly_detection', seasonal_patterns='Monthly', mask_rate=0.25, anomaly_ratio=1.0, class_dropout=0.05)
# Use GPU: cuda:0
# >>>>>>>testing : SMAP_ModernTCN_SMAP_ftM_dim32_nb1_lk51_sk5_ffr1_ps8_str4_multiFalse_mergedFalse_Exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test: (427617, 25)
# train: (135183, 25)
# test 427522
# test: (427617, 25)
# train: (135183, 25)
# train 135088
# loading model
# Threshold : 5.8932195
# pred:    (41042112,)
# gt:      (41042112,)
# Saved test_input/output (21.4 MB each, float16, sub=96)
# pred:  (41042112,)
# gt:    (41042112,)
# Accuracy : 0.9335, Precision : 0.9029, Recall : 0.5385, F-score : 0.6746, AUC : 0.4442, AU-PR : 0.1136

# %% [markdown]
# ### SWaT Dataset

# %%
# !CUDA_VISIBLE_DEVICES=2 python -u run.py \
  --task_name anomaly_detection \
  --anomaly_ratio 0.5 \
  --is_training 0 \
  --root_path ./all_datasets/SWaT/ \
  --model_id SWAT \
  --model ModernTCN \
  --data SWAT \
  --seq_len 100 \
  --label_len 0 \
  --pred_len 0 \
  --enc_in 51 \
  --c_out 51 \
  --ffn_ratio 1 \
  --patch_size 8 \
  --patch_stride 4 \
  --num_blocks 1 \
  --large_size 51 \
  --small_size 5 \
  --dims 64 \
  --head_dropout 0.0 \
  --dropout 0.1 \
  --itr 1 \
  --learning_rate 0.0003 \
  --batch_size 128 \
  --train_epochs 10 \
  --patience 3 \
  --des Exp \
  --use_multi_scale False \
  --small_kernel_merged False
# Out:
# Args in experiment:
# Namespace(random_seed=2021, is_training=0, model_id='SWAT', model='ModernTCN', data='SWAT', root_path='./all_datasets/SWaT/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', embed='timeF', seq_len=100, label_len=0, pred_len=0, stem_ratio=6, downsample_ratio=2, ffn_ratio=1, patch_size=8, patch_stride=4, num_blocks=[1], large_size=[51], small_size=[5], dims=[64], dw_dims=[256, 256, 256, 256], small_kernel_merged=False, call_structural_reparam=False, use_multi_scale=False, fc_dropout=0.05, head_dropout=0.0, patch_len=16, stride=8, padding_patch='end', revin=1, affine=0, subtract_last=0, decomposition=0, kernel_size=25, individual=0, embed_type=0, enc_in=51, dec_in=7, c_out=51, d_model=512, n_heads=8, e_layers=2, d_layers=1, d_ff=2048, moving_avg=25, factor=1, distil=True, dropout=0.1, activation='gelu', output_attention=False, do_predict=False, num_workers=10, itr=1, train_epochs=10, batch_size=128, patience=3, learning_rate=0.0003, des='Exp', loss='mse', lradj='type1', pct_start=0.3, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', test_flop=False, task_name='anomaly_detection', seasonal_patterns='Monthly', mask_rate=0.25, anomaly_ratio=0.5, class_dropout=0.05)
# Use GPU: cuda:0
# >>>>>>>testing : SWAT_ModernTCN_SWAT_ftM_dim64_nb1_lk51_sk5_ffr1_ps8_str4_multiFalse_mergedFalse_Exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test: (449919, 51)
# train: (495000, 51)
# test 449820
# test: (449919, 51)
# train: (495000, 51)
# train 494901
# loading model
# Threshold : 0.44118744
# pred:    (44982000,)
# gt:      (44982000,)
# Saved test_input/output (45.9 MB each, float16, sub=100)
# Saved raw scores and labels for PR curve (SWAT)
# pred:  (44982000,)
# gt:    (44982000,)
# Accuracy : 0.9796, Precision : 0.9585, Recall : 0.8697, F-score : 0.9119, AUC : 0.2465, AU-PR : 0.0960

# %% [markdown]
# ### PSM Dataset

# %%
# !CUDA_VISIBLE_DEVICES=2 python -u run.py \
  --task_name anomaly_detection \
  --anomaly_ratio 1 \
  --is_training 0 \
  --root_path ./all_datasets/PSM/ \
  --model_id PSM \
  --model ModernTCN \
  --data PSM \
  --seq_len 100 \
  --label_len 0 \
  --pred_len 0 \
  --enc_in 25 \
  --c_out 25 \
  --ffn_ratio 1 \
  --patch_size 8 \
  --patch_stride 4 \
  --num_blocks 1 \
  --large_size 51 \
  --small_size 5 \
  --dims 32 \
  --head_dropout 0.0 \
  --dropout 0.1 \
  --itr 1 \
  --learning_rate 0.0003 \
  --batch_size 128 \
  --train_epochs 10 \
  --patience 3 \
  --des Exp \
  --use_multi_scale False \
  --small_kernel_merged False
# Out:
# Args in experiment:
# Namespace(random_seed=2021, is_training=0, model_id='PSM', model='ModernTCN', data='PSM', root_path='./all_datasets/PSM/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', embed='timeF', seq_len=100, label_len=0, pred_len=0, stem_ratio=6, downsample_ratio=2, ffn_ratio=1, patch_size=8, patch_stride=4, num_blocks=[1], large_size=[51], small_size=[5], dims=[32], dw_dims=[256, 256, 256, 256], small_kernel_merged=False, call_structural_reparam=False, use_multi_scale=False, fc_dropout=0.05, head_dropout=0.0, patch_len=16, stride=8, padding_patch='end', revin=1, affine=0, subtract_last=0, decomposition=0, kernel_size=25, individual=0, embed_type=0, enc_in=25, dec_in=7, c_out=25, d_model=512, n_heads=8, e_layers=2, d_layers=1, d_ff=2048, moving_avg=25, factor=1, distil=True, dropout=0.1, activation='gelu', output_attention=False, do_predict=False, num_workers=10, itr=1, train_epochs=10, batch_size=128, patience=3, learning_rate=0.0003, des='Exp', loss='mse', lradj='type1', pct_start=0.3, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', test_flop=False, task_name='anomaly_detection', seasonal_patterns='Monthly', mask_rate=0.25, anomaly_ratio=1.0, class_dropout=0.05)
# Use GPU: cuda:0
# >>>>>>>testing : PSM_ModernTCN_PSM_ftM_dim32_nb1_lk51_sk5_ffr1_ps8_str4_multiFalse_mergedFalse_Exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test: (87841, 25)
# train: (132481, 25)
# test 87742
# test: (87841, 25)
# train: (132481, 25)
# train 132382
# loading model
# Threshold : 0.3417909
# pred:    (8774200,)
# gt:      (8774200,)
# Saved test_input/output (4.4 MB each, float16, sub=100)
# Saved raw scores and labels for PR curve (PSM)
# pred:  (8774200,)
# gt:    (8774200,)
# Accuracy : 0.9809, Precision : 0.9874, Recall : 0.9432, F-score : 0.9648, AUC : 0.5893, AU-PR : 0.3829

# %% [markdown]
# ## Parameter Count

# %%
# ── Parameter count for ModernTCN (anomaly detection) ───────────────────
import sys, argparse
import torch
import numpy as np

# Assumes you're in ModernTCN-detection (the notebook already does %cd there)
sys.path.insert(0, './')
from models.ModernTCN import Model as ModernTCN

datasets = {
    'SMD':  dict(seq_len=100, label_len=0, pred_len=0, enc_in=38, c_out=38,
                 ffn_ratio=1, patch_size=8, patch_stride=4,
                 num_blocks=[1], large_size=[51], small_size=[5], dims=[64],
                 dropout=0.1, head_dropout=0.0,
                 use_multi_scale=False, small_kernel_merged=False),

    'MSL':  dict(seq_len=100, label_len=0, pred_len=0, enc_in=55, c_out=55,
                 ffn_ratio=1, patch_size=8, patch_stride=4,
                 num_blocks=[1], large_size=[51], small_size=[5], dims=[64],
                 dropout=0.1, head_dropout=0.0,
                 use_multi_scale=False, small_kernel_merged=False),

    'SMAP': dict(seq_len=100, label_len=0, pred_len=0, enc_in=25, c_out=25,
                 ffn_ratio=1, patch_size=8, patch_stride=4,
                 num_blocks=[1], large_size=[51], small_size=[5], dims=[32],
                 dropout=0.1, head_dropout=0.0,
                 use_multi_scale=False, small_kernel_merged=False),

    'SWaT': dict(seq_len=100, label_len=0, pred_len=0, enc_in=51, c_out=51,
                 ffn_ratio=1, patch_size=8, patch_stride=4,
                 num_blocks=[1], large_size=[51], small_size=[5], dims=[64],
                 dropout=0.1, head_dropout=0.0,
                 use_multi_scale=False, small_kernel_merged=False),

    'PSM':  dict(seq_len=100, label_len=0, pred_len=0, enc_in=25, c_out=25,
                 ffn_ratio=1, patch_size=8, patch_stride=4,
                 num_blocks=[1], large_size=[51], small_size=[5], dims=[32],
                 dropout=0.1, head_dropout=0.0,
                 use_multi_scale=False, small_kernel_merged=False),
}

print(f"{'Dataset':<8} {'Total Params':>14} {'Trainable':>14} {'Non-trainable':>15} {'MB (fp32)':>10}")
print("-" * 67)

for name, hp in datasets.items():
    cfg = argparse.Namespace(
        task_name='anomaly_detection',
        stem_ratio=6, downsample_ratio=2,
        freq='h',
        # misc flags used by the model wrapper
        revin=1, affine=0, subtract_last=0,
        decomposition=0, kernel_size=25, individual=0,
        # keep it consistent with dims:
        dw_dims=hp['dims'],
        **hp,
    )

    model = ModernTCN(cfg).cpu().eval()

    total     = sum(p.numel() for p in model.parameters())
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    frozen    = total - trainable
    mb_fp32   = total * 4 / 1e6  # params * 4 bytes (float32)

    print(f"{name:<8} {total:>14,} {trainable:>14,} {frozen:>15,} {mb_fp32:>10.2f}")
# Out:
# Dataset    Total Params      Trainable   Non-trainable  MB (fp32)
# -------------------------------------------------------------------
# SMD             653,000        653,000               0       2.61
# MSL           1,064,264      1,064,264               0       4.26
# SMAP            143,016        143,016               0       0.57
# SWaT            960,840        960,840               0       3.84
# PSM             143,016        143,016               0       0.57
# /home/fzf/.conda/envs/moderntcn/lib/python3.9/site-packages/torch/nn/init.py:582: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")

# %% [markdown]
# ## Number of Operations

# %%
import warnings
warnings.filterwarnings("ignore", message="Initializing zero-element tensors is a no-op")

# ── Count MACs for ModernTCN (anomaly detection) on ALL datasets ─────────
import sys, argparse
import torch
import torch.nn as nn

# Assumes you're in ModernTCN-detection (the notebook already does %cd there)
sys.path.insert(0, './')
from models.ModernTCN import Model as ModernTCN
from fvcore.nn import FlopCountAnalysis
from thop import profile

class _Wrap(nn.Module):
    def __init__(self, m):
        super().__init__()
        self.inner = m
    def forward(self, x):
        return self.inner(x, None, None, None)

datasets = {
    'SMD':  dict(seq_len=100, label_len=0, pred_len=0, enc_in=38, c_out=38,
                 ffn_ratio=1, patch_size=8, patch_stride=4,
                 num_blocks=[1], large_size=[51], small_size=[5], dims=[64],
                 dropout=0.1, head_dropout=0.0,
                 use_multi_scale=False, small_kernel_merged=False),

    'MSL':  dict(seq_len=100, label_len=0, pred_len=0, enc_in=55, c_out=55,
                 ffn_ratio=1, patch_size=8, patch_stride=4,
                 num_blocks=[1], large_size=[51], small_size=[5], dims=[64],
                 dropout=0.1, head_dropout=0.0,
                 use_multi_scale=False, small_kernel_merged=False),

    'SMAP': dict(seq_len=100, label_len=0, pred_len=0, enc_in=25, c_out=25,
                 ffn_ratio=1, patch_size=8, patch_stride=4,
                 num_blocks=[1], large_size=[51], small_size=[5], dims=[32],
                 dropout=0.1, head_dropout=0.0,
                 use_multi_scale=False, small_kernel_merged=False),

    'SWaT': dict(seq_len=100, label_len=0, pred_len=0, enc_in=51, c_out=51,
                 ffn_ratio=1, patch_size=8, patch_stride=4,
                 num_blocks=[1], large_size=[51], small_size=[5], dims=[64],
                 dropout=0.1, head_dropout=0.0,
                 use_multi_scale=False, small_kernel_merged=False),

    'PSM':  dict(seq_len=100, label_len=0, pred_len=0, enc_in=25, c_out=25,
                 ffn_ratio=1, patch_size=8, patch_stride=4,
                 num_blocks=[1], large_size=[51], small_size=[5], dims=[32],
                 dropout=0.1, head_dropout=0.0,
                 use_multi_scale=False, small_kernel_merged=False),
}

print(f"{'Dataset':<8} {'fvcore MACs':>14} {'thop MACs':>14} {'Diff%':>10}")
print("-" * 50)

for name, hp in datasets.items():
    cfg = argparse.Namespace(
        task_name='anomaly_detection',
        stem_ratio=6, downsample_ratio=2,
        freq='h',
        # misc flags used by the model wrapper
        revin=1, affine=0, subtract_last=0,
        decomposition=0, kernel_size=25, individual=0,
        # keep it consistent with dims:
        dw_dims=hp['dims'],
        **hp,
    )
    model = ModernTCN(cfg).cpu().eval()
    wrapped = _Wrap(model)
    torch.manual_seed(42)
    dummy = torch.randn(1, cfg.seq_len, cfg.enc_in)

    with torch.no_grad():
        # fvcore
        fa = FlopCountAnalysis(wrapped, dummy)
        fa.unsupported_ops_warnings(False)
        fa.uncalled_modules_warnings(False)
        fvcore_macs = fa.total()

        # thop
        thop_macs, _ = profile(wrapped, inputs=(dummy,), verbose=False)

    diff_pct = abs(fvcore_macs - thop_macs) / max(fvcore_macs, 1) * 100
    print(f"{name:<8} {fvcore_macs:>14,} {thop_macs:>14,.0f} {diff_pct:>9.4f}%")
# Out:
# Dataset     fvcore MACs      thop MACs      Diff%
# --------------------------------------------------
# SMD          17,145,600     17,510,400    2.1277%
# MSL          27,808,000     28,336,000    1.8987%
# SMAP          3,840,000      3,960,000    3.1250%
# SWaT         25,132,800     25,622,400    1.9481%
# PSM           3,840,000      3,960,000    3.1250%

# %% [markdown]
# ## Memory Usage

# %%
# ── Memory usage for ModernTCN Anomaly Detection (batch_size=128) ─────────
import os, sys, argparse
import numpy as np
import torch
import torch.nn as nn

# Assumes you're in ModernTCN-detection (the notebook already does %cd there)
sys.path.insert(0, "./")

os.environ["CUDA_VISIBLE_DEVICES"] = "3"  

from exp.exp_anomaly_detection import Exp_Anomaly_Detection

if not torch.cuda.is_available():
    raise RuntimeError("CUDA is not available. Run this cell on a GPU machine or switch to a CUDA-enabled PyTorch install.")

# ── Force CUDA initialization ───────────────────────────────────────────
_ = torch.zeros(1).cuda()
device = torch.device("cuda:0")
print(f"Using device: {torch.cuda.get_device_name(0)}")


DATASETS = {
    'SMD':  dict(seq_len=100, label_len=0, pred_len=0, enc_in=38, c_out=38,
                 ffn_ratio=1, patch_size=8, patch_stride=4,
                 num_blocks=[1], large_size=[51], small_size=[5], dims=[64],
                 dropout=0.1, head_dropout=0.0,
                 use_multi_scale=False, small_kernel_merged=False),

    'MSL':  dict(seq_len=100, label_len=0, pred_len=0, enc_in=55, c_out=55,
                 ffn_ratio=1, patch_size=8, patch_stride=4,
                 num_blocks=[1], large_size=[51], small_size=[5], dims=[64],
                 dropout=0.1, head_dropout=0.0,
                 use_multi_scale=False, small_kernel_merged=False),

    'SMAP': dict(seq_len=100, label_len=0, pred_len=0, enc_in=25, c_out=25,
                 ffn_ratio=1, patch_size=8, patch_stride=4,
                 num_blocks=[1], large_size=[51], small_size=[5], dims=[32],
                 dropout=0.1, head_dropout=0.0,
                 use_multi_scale=False, small_kernel_merged=False),

    'SWaT': dict(seq_len=100, label_len=0, pred_len=0, enc_in=51, c_out=51,
                 ffn_ratio=1, patch_size=8, patch_stride=4,
                 num_blocks=[1], large_size=[51], small_size=[5], dims=[64],
                 dropout=0.1, head_dropout=0.0,
                 use_multi_scale=False, small_kernel_merged=False),

    'PSM':  dict(seq_len=100, label_len=0, pred_len=0, enc_in=25, c_out=25,
                 ffn_ratio=1, patch_size=8, patch_stride=4,
                 num_blocks=[1], large_size=[51], small_size=[5], dims=[32],
                 dropout=0.1, head_dropout=0.0,
                 use_multi_scale=False, small_kernel_merged=False),
}

# ── Fixed args shared across all datasets ───────────────────────────────
BASE_ARGS = dict(
    task_name="anomaly_detection",
    is_training=0,
    model="ModernTCN",
    features="M", target="OT", freq="h", embed="timeF",
    checkpoints="./checkpoints/",
    # run.py defaults used when scripts omit values
    seq_len=96, label_len=48, pred_len=96,
    stem_ratio=6, downsample_ratio=2,
    ffn_ratio=2, patch_size=16, patch_stride=8,
    num_blocks=[1, 1, 1, 1],
    large_size=[31, 29, 27, 13],
    small_size=[5, 5, 5, 5],
    dims=[256, 256, 256, 256],
    dw_dims=[256, 256, 256, 256],
    small_kernel_merged=False,
    use_multi_scale=True,
    call_structural_reparam=False,
    # misc flags used by model wrapper
    revin=1, affine=0, subtract_last=0,
    decomposition=0, kernel_size=25, individual=0,
    dropout=0.1, head_dropout=0.0, fc_dropout=0.05,
    # optimization (only used for training; still needed for Exp to exist)
    batch_size=128, train_epochs=1, patience=10, learning_rate=0.0005,
    pct_start=0.3, lradj="type1", loss="mse", use_amp=False,
    num_workers=10, itr=1, des="Exp",
    # GPU
    use_gpu=True, gpu=0, use_multi_gpu=False, devices="0,1,2,3",
)

# ── Measure memory for each dataset ─────────────────────────────────────
results = {}

for dataset_name, ds_args in DATASETS.items():
    print(f"Measuring {dataset_name}...")
    try:
        # Build args
        args_dict = {**BASE_ARGS, **ds_args}
        # Keep dw_dims consistent with dims when overridden
        args_dict["dw_dims"] = list(args_dict["dims"])
        args = argparse.Namespace(**args_dict)

        # Clear GPU memory from previous iteration
        torch.cuda.empty_cache()
        torch.cuda.reset_peak_memory_stats(device)
        baseline = torch.cuda.memory_allocated(device)

        # Load model on GPU via the repo's experiment wrapper
        exp = Exp_Anomaly_Detection(args)
        model = exp.model
        weight_mem = (torch.cuda.memory_allocated(device) - baseline) / 1e6

        # Dummy input matching dataset dimensions
        dummy = torch.randn(args.batch_size, args.seq_len, args.enc_in, device=device)
        criterion = nn.MSELoss()

        # Peak training memory (forward + backward)
        model.train()
        model.zero_grad(set_to_none=True)
        torch.cuda.reset_peak_memory_stats(device)
        output = model(dummy, None, None, None)
        loss = criterion(output, dummy)
        loss.backward()
        peak_train = torch.cuda.max_memory_allocated(device) / 1e6

        # Peak inference memory (no gradients)
        model.eval()
        torch.cuda.reset_peak_memory_stats(device)
        with torch.no_grad():
            _ = model(dummy, None, None, None)
        peak_infer = torch.cuda.max_memory_allocated(device) / 1e6

        total_params = sum(p.numel() for p in model.parameters())

        results[dataset_name] = {
            "params":       total_params,
            "weight_exact": total_params * 4 / 1e6,  # params × 4 bytes → MB
            "weight_mb":    weight_mem,              # allocated after model init (includes buffers)
            "train_mb":     peak_train,
            "infer_mb":     peak_infer,
            "overhead_mb":  peak_train - weight_mem,
        }

        # Clean up before next dataset
        del model, exp, dummy, output, loss
        torch.cuda.empty_cache()

    except Exception as e:
        print(f"  ERROR: {e}")
        results[dataset_name] = None

# ── Print summary table ────────────────────────────────────────────────
print("\n" + "=" * 95)
print("MEMORY SUMMARY — ModernTCN Anomaly Detection (batch_size=128)")
print("=" * 95)
print(f"{'Dataset':<8} {'Params':<12} {'Weights exact':<15} {'Weights GPU':<13} "
      f"{'Train peak':<13} {'Infer peak':<13} {'Overhead':<10}")
print(f"{'':>20} {'(params×4B)':>15} {'(allocated)':>13} "
      f"{'(MB)':>13} {'(MB)':>13} {'(MB)':>10}")
print("-" * 95)
for name, r in results.items():
    if r is None:
        print(f"{name:<8} ERROR")
    else:
        print(f"{name:<8} {r['params']:>10,}   {r['weight_exact']:>11.2f} MB  "
              f"{r['weight_mb']:>9.2f} MB  "
              f"{r['train_mb']:>9.2f} MB  "
              f"{r['infer_mb']:>9.2f} MB  "
              f"{r['overhead_mb']:>7.2f} MB")
# Out:
# Using device: NVIDIA GeForce RTX 2080
# Measuring SMD...
# Use GPU: cuda:0
# Measuring MSL...
# Use GPU: cuda:0
# Measuring SMAP...
# Use GPU: cuda:0
# Measuring SWaT...
# Use GPU: cuda:0
# Measuring PSM...
# Use GPU: cuda:0
#
# ===============================================================================================
# MEMORY SUMMARY — ModernTCN Anomaly Detection (batch_size=128)
# ===============================================================================================
# Dataset  Params       Weights exact   Weights GPU   Train peak    Infer peak    Overhead
#                          (params×4B)   (allocated)          (MB)          (MB)       (MB)
# -----------------------------------------------------------------------------------------------
# SMD         653,000          2.61 MB       2.65 MB     470.28 MB     188.19 MB   467.62 MB
# MSL       1,064,264          4.26 MB       4.32 MB     669.29 MB     264.98 MB   664.96 MB
# SMAP        143,016          0.57 MB       0.59 MB     176.75 MB      79.37 MB   176.15 MB
# SWaT        960,840          3.84 MB       3.90 MB     623.31 MB     247.19 MB   619.41 MB
# PSM         143,016          0.57 MB       0.59 MB     176.80 MB      79.92 MB   176.20 MB

# %% [markdown]
# ## Inference Speed

# %%
# ── Inference speed for ModernTCN on ALL datasets (CUDA Events) ───────────
import torch
import argparse
import numpy as np
import sys
import os

# Assumes you're in ModernTCN-detection (the notebook already does %cd there)
sys.path.insert(0, './')

from exp.exp_anomaly_detection import Exp_Anomaly_Detection

# Reuse DATASETS/BASE_ARGS from the Memory Usage cell above
if 'DATASETS' not in globals() or 'BASE_ARGS' not in globals():
    raise RuntimeError("Run the Memory Usage cell first (it defines DATASETS and BASE_ARGS).")

# Use the same device already initialized above if available
device = globals().get('device', torch.device('cuda:0'))
if not torch.cuda.is_available():
    raise RuntimeError('CUDA is not available.')
print(f"Using device: {torch.cuda.get_device_name(0)}")

N_WARMUP = 10
N_RUNS   = 100

# ── Measure each dataset ──────────────────────────────────────────────
speed_results = {}

for dataset_name, ds_args in DATASETS.items():
    print(f"Measuring {dataset_name}...", end=" ", flush=True)
    try:
        # Build args (and keep dw_dims consistent with dims when overridden)
        args_dict = {**BASE_ARGS, **ds_args}
        args_dict['dw_dims'] = list(args_dict['dims'])
        args = argparse.Namespace(**args_dict)

        torch.cuda.empty_cache()
        exp   = Exp_Anomaly_Detection(args)
        model = exp.model
        model.eval()

        dummy = torch.randn(args.batch_size, args.seq_len, args.enc_in, device=device)

        # Warmup: GPU needs a few passes to reach steady state
        with torch.no_grad():
            for _ in range(N_WARMUP):
                _ = model(dummy, None, None, None)

        # Measure using CUDA Events (GPU-side timestamps, not CPU timer)
        times_ms = []
        with torch.no_grad():
            for _ in range(N_RUNS):
                start = torch.cuda.Event(enable_timing=True)
                end   = torch.cuda.Event(enable_timing=True)
                torch.cuda.synchronize()
                start.record()
                _ = model(dummy, None, None, None)
                end.record()
                torch.cuda.synchronize()
                times_ms.append(start.elapsed_time(end))

        times_ms = np.asarray(times_ms, dtype=np.float64)

        speed_results[dataset_name] = {
            'latency_mean_ms': float(times_ms.mean()),
            'latency_std_ms':  float(times_ms.std(ddof=0)),
            'latency_min_ms':  float(times_ms.min()),
            'latency_max_ms':  float(times_ms.max()),
            'throughput':      float(args.batch_size / (times_ms.mean() / 1000.0)),
            's_per_iter':      float(times_ms.mean() / 1000.0),
            'seq_len':         int(args.seq_len),
            'enc_in':          int(args.enc_in),
            'batch_size':      int(args.batch_size),
        }
        print(f"done ({times_ms.mean():.2f} ms)")

        del model, exp, dummy
        torch.cuda.empty_cache()

    except Exception as e:
        print(f"ERROR: {e}")
        speed_results[dataset_name] = None

# ── Print summary table ────────────────────────────────────────────────
print("" + "=" * 98)
print(f"INFERENCE SPEED SUMMARY — ModernTCN Anomaly Detection (batch_size={BASE_ARGS.get('batch_size', 'NA')}, N={N_RUNS} runs)")
print("=" * 98)
print(f"{'Dataset':<8} {'seq_len':<9} {'enc_in':<8} {'B':<4} {'Latency mean±std (ms)':<26} {'Throughput (samp/s)':<22} {'s/iter'}")
print("-" * 98)
for name, r in speed_results.items():
    if r is None:
        print(f"{name:<8} ERROR")
    else:
        lat = f"{r['latency_mean_ms']:.3f} ± {r['latency_std_ms']:.3f}"
        print(f"{name:<8} {r['seq_len']:<9} {r['enc_in']:<8} {r['batch_size']:<4} {lat:<26} {r['throughput']:>18,.1f}     {r['s_per_iter']:.4f}")
# Out:
# Using device: NVIDIA GeForce RTX 2080
# Measuring SMD... Use GPU: cuda:0
# done (6.55 ms)
# Measuring MSL... Use GPU: cuda:0
# done (8.82 ms)
# Measuring SMAP... Use GPU: cuda:0
# done (12.39 ms)
# Measuring SWaT... Use GPU: cuda:0
# done (8.24 ms)
# Measuring PSM... Use GPU: cuda:0
# done (12.38 ms)
# ==================================================================================================
# INFERENCE SPEED SUMMARY — ModernTCN Anomaly Detection (batch_size=128, N=100 runs)
# ==================================================================================================
# Dataset  seq_len   enc_in   B    Latency mean±std (ms)      Throughput (samp/s)    s/iter
# --------------------------------------------------------------------------------------------------
# SMD      100       38       128  6.551 ± 0.442                        19,538.6     0.0066
# MSL      100       55       128  8.818 ± 0.038                        14,516.0     0.0088
# SMAP     100       25       128  12.390 ± 0.050                       10,330.8     0.0124
# SWaT     100       51       128  8.238 ± 0.010                        15,537.5     0.0082
# PSM      100       25       128  12.377 ± 0.044                       10,342.2     0.0124
